# %% [markdown]
# # Analysis of Daily Sports and Activities using Motion Sensors
#
# ### Summary
#
# <p> The aim of this notebook is to analyze the sensor data from the Daily Sports and Activities Dataset provided at UCI machine learning repo, and build a robust Activity classifier based on it.</p>
# <p> <b>Dataset Definition:</b><br> Each of the 19 activities is performed by eight subjects (4 female, 4 male, between the ages 20 and 30) for 5 minutes.  </p>
#
# <p> Total signal duration is 5 minutes for each activity of each subject.
# String inter-subject variations in the speeds and amplitudes of some activities. </p>
#
# <p> The activities are performed at the Bilkent University Sports Hall, in the Electrical and Electronics Engineering Building, and in a flat outdoor area on campus. Sensor units are calibrated to acquire data at 25 Hz sampling frequency. The 5-min signals are divided into 5-sec segments so that 480(=60x8) signal segments are obtained for each activity. </p>
#
# <p> The 19 activities are:<br>
# sitting (A1),<br>
# standing (A2),<br>
# lying on back and on right side (A3 and A4),<br>
# ascending and descending stairs (A5 and A6),<br>
# standing in an elevator still (A7)<br>
# and moving around in an elevator (A8),<br>
# walking in a parking lot (A9),<br>
# walking on a treadmill with a speed of 4 km/h (in flat and 15 deg inclined positions) (A1
# 0 and A11),<br>
# running on a treadmill with a speed of 8 km/h (A12),<br>
# exercising on a stepper (A13),<br>
# exercising on a cross trainer (A14),<br>
# cycling on an exercise bike in horizontal and vertical positions (A15 and A16),
# rowing (A17),<br>
# jumping (A18),<br>
# and playing basketball (A19). </p>
#
# <p> <b>For convenience, we're shifting the identifying number of each activity and person down by one such that activity-1 is represented by 0 and so on.</b> </p>

# %% [markdown]
# The following modules and libraries are used for this notebook, the need for each of which is defined in the comments:

# %%
#for monitoring training time and performance of various models while hyperparameter tuning
import time

#transformation and statistical operations
import numpy as np
import scipy.stats as ss
from scipy import fft

#for importing datasets
import os
import sklearn.datasets
from sklearn import decomposition

#ML and Metrics
from sklearn import metrics
from sklearn.naive_bayes import BernoulliNB

#DL
import keras
from keras.models import Sequential
from keras.layers import LSTM,GRU,Dense,Activation,Dropout

#visualizations
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sn

# %% [markdown]
# ### Importing the Dataset
# <p> File structure tree definition:<br>
#
# folder: 19 activities (a) (in the order given above)<br>
# subfolder: 8 subjects (p)<br>
# Textfiles: 60 segments(5secs each, sampled @25khz) (s)<br>
# Within Textfiles:<br>
# 5 units on torso (T), right arm (RA), left arm (LA), right leg (RL), left leg (LL)<br>
# 9 sensors on each unit (x,y,z accelerometers, x,y,z gyroscopes, x,y,z magnetometers)<br>
#  </p>
#
# <p>importing the dataset was a bit tricky because of the raw file format and structure. the import was performed using nested loops and scikit-learn's  datasert library</p>
#  <p>The data is parsed and arranged in a multi dimensional numpy array, indexed as:<br>
#  [activity 0-18][persons 0-7][segments 0-59][samples 0-124][sensor readings 0-44]</p>

# %%
data = [a for a in range(19)]
#starting indices from zero for convenience
#output = data = [activity 0-18][persons 0-7][segments 0-59][n 0-124]
#series[]
for a in range(19):
    zr = "0" if a+1<10 else ""
    x = sklearn.datasets.load_files("sensor_dataset/a"+zr+str(a+1),shuffle=False,load_content=True,encoding="utf-8")
    inc = 0
    data[a] = [p for p in range(8)]
    for p in range(8):
        data[a][p] = [x.data[n].splitlines() for n in range(inc,inc+60)];
        inc+=60
        for s in range(60):
            for n in range(125):
                data[a][p][s][n] = np.array([v for v in data[a][p][s][n].split(',')]).astype(np.float32)

data_set = np.array(data)
print(data_set.shape)
# Out:
# (19, 8, 60, 125, 45)

# %% [markdown]
# The next two operations involve further decomposing the dataset to define sensor outputs from unique units, and subsampling the time series to get 5 x 60 second feature vectors

# %%
#5 units x 9 sensor outputs
per_sensor = np.reshape(data_set,[19, 8, 60*125,5,9])
#uniform subsampling of 7500 samples@25hz to 5x60sec 
X = per_sensor[:,:,::25]
X.shape
# Out:
# (19, 8, 300, 5, 9)

# %% [markdown]
# ### Data Exploration
#
# We can quickly get a rough idea of the various activities' sensor data by plotting the means of different units(torso, left arm, right arm, left leg, right leg) in a time series. we make the following observations:<br>
# * We notice that semi static activities such as standing and sitting have very miniscule spreads as compared to more complex activities.
# * Some activities like jumping and running seem to have somewhat periodic fluctuations
# * Other activities such as basketball are extremely random and should pose a major threat to proper classification
# * We also notice that certain activities are performed almost similarly by all subjects while some activities are performed very differently by the different subjects.
# <br>Feel free to plot and compare the various activities and subject relations by modifying the following snippet.
# <br>eg plt.plot(x_mean[6,0,:,:] plots the data of the 7th\* activity performed by the 1st\* subject
# <br>*(because indexes start from 0)

# %%
#plotting some sensor data
x_mean = X.mean(axis=4)
print(x_mean.shape)
plt.figure(figsize=[18,16])
plt.subplot(321)
plt.plot(x_mean[6,0,:,:])
plt.title("standing in elevator(still)")
plt.legend(["T","RA","LA","RL","LL"], loc=1)
plt.subplot(322)
plt.plot(x_mean[9,0,:,:])
plt.legend(["T","RA","LA","RL","LL"], loc=1)
plt.title("treadmill running")
plt.legend()
plt.subplot(323)
plt.plot(x_mean[17,0,:,:])
plt.legend(["T","RA","LA","RL","LL"], loc=1)
plt.title("jumping")
plt.legend()
plt.subplot(324)
plt.plot(x_mean[18,0,:,:])
plt.legend(["T","RA","LA","RL","LL"], loc=1)
plt.title("basketball")
plt.legend()
# Out:
# (19, 8, 300, 5)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# #### Custom Feature extraction
# Along with the mean values, we are generating 6 more feature vectors based on the following operations:
# * minimum and maximum
# * skewness
# * variance
# * kurtosis

# %%
x_variance = X.var(axis=4)
x_skew = ss.skew(X,axis=4)
x_kurt = ss.kurtosis(X,axis=4)
x_min = X.min(axis=4)
x_max = X.max(axis=4)

print(x_variance.shape)
print(x_skew.shape)
print(x_kurt.shape)
print(x_min.shape)
print(x_max.shape)
# Out:
# (19, 8, 300, 5)
# (19, 8, 300, 5)
# (19, 8, 300, 5)
# (19, 8, 300, 5)
# (19, 8, 300, 5)

# %% [markdown]
# #### Plotting the custom features

# %%
#60 seconds
plt.figure(figsize=[18,16])
plt.subplot(321)
plt.plot(x_variance[17,0,:60])
plt.title("jumping_variance")
plt.legend(["T","RA","LA","RL","LL"], loc=1)
plt.subplot(322)
plt.plot(x_skew[17,0,:60])
plt.legend(["T","RA","LA","RL","LL"], loc=1)
plt.title("jumping_skewness")
plt.legend()
plt.subplot(323)
plt.plot(x_kurt[17,0,:60])
plt.legend(["T","RA","LA","RL","LL"], loc=1)
plt.title("jumping_kurtosis")
plt.legend()
plt.subplot(324)
plt.plot(x_mean[17,0,:60])
plt.legend(["T","RA","LA","RL","LL"], loc=1)
plt.title("jumping_mean")
plt.legend()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# ### Generating Feature Vectors
#
# We are devising 4 variations of the Feature vectors which are as follows:
# * flattened_x: raw sensor data(5 units x 3 sensors x 3 axis readings) of the shape (19, 8, 300, 45)
# * custom_feature_vecs: Concatenated Custom features from our previous custom feature extraction(5 units x 6 operations) (19, 8, 300, 30)
# * hybrid_vec: A combination of flattened_x and custom features (19, 8, 300, 75)
# * small_x: small version of flattened_x with 5 activities only for performance testing purposes (5, 8, 300, 45)

# %%
flattened_x = np.reshape(X,[19,8,300,5*9])
custom_feature_vecs = np.concatenate([x_min,x_max,x_mean,x_variance,x_skew,x_kurt],axis=3)
hybrid_vec = np.concatenate([flattened_x,x_min,x_max,x_mean,x_variance,x_skew,x_kurt],axis=3)
print(flattened_x.shape)
print(custom_feature_vecs.shape)
print(hybrid_vec.shape)
#first 5 activities only
small_x = flattened_x[:5]
print(small_x.shape)
# Out:
# (19, 8, 300, 45)
# (19, 8, 300, 30)
# (19, 8, 300, 75)
# (5, 8, 300, 45)

# %% [markdown]
# ### Splitting Training and Test Data
#
# The data is assorted in such a way that for each activity is performed such that the first 4 subjects are male and the next 4 are female. A general conjecture can suggest that while each activity's sensor data might have strong similaries accross all subjects, there should a strong variance between the male and female subjects. So if we need to split the subjects for testing data, the best way to do so should be to extract one subject from each sex and use the remaining 6 subjects for training data. This might initially reduce the test accuracy but will result in more accurate global results.

# %%
#raw feature splits
train_x_m = np.split(flattened_x,[3,8],axis=1)[0]
train_x_f = np.split(flattened_x,[4,7,8],axis=1)[1]
test_x_m = np.split(flattened_x,[3,4,8],axis=1)[1]
test_x_f = np.split(flattened_x,[7,8],axis=1)[1]
train_x = np.reshape(np.concatenate((train_x_m,train_x_f),axis=1),[19*6,300,45])
test_x = np.reshape(np.concatenate((test_x_m,test_x_f),axis=1),[19*2,300,45])
train_y = np.expand_dims(np.repeat([i for i in range(19)],6),axis=1)
test_y = np.expand_dims(np.repeat([i for i in range(19)],2),axis=1)
print(train_x.shape, train_y.shape, test_x.shape, test_y.shape)
# Out:
# (114, 300, 45) (114, 1) (38, 300, 45) (38, 1)

# %%
#small splitset for testing purposes
train_small_x_m = np.split(small_x,[3,8],axis=1)[0]
train_small_x_f = np.split(small_x,[4,7,8],axis=1)[1]
test_small_x_m = np.split(small_x,[3,4,8],axis=1)[1]
test_small_x_f = np.split(small_x,[7,8],axis=1)[1]
train_small_x = np.reshape(np.concatenate((train_small_x_m,train_small_x_f),axis=1),[5*6,300,45])
test_small_x = np.reshape(np.concatenate((test_small_x_m,test_small_x_f),axis=1),[5*2,300,45])
train_small_y = np.expand_dims(np.repeat([i for i in range(5)],6),axis=1)
test_small_y = np.expand_dims(np.repeat([i for i in range(5)],2),axis=1)
print(train_small_x.shape, train_small_y.shape, test_small_x.shape, test_small_y.shape)
# Out:
# (30, 300, 45) (30, 1) (10, 300, 45) (10, 1)

# %%
#custom feature splits
#pulling activity value one down to match indices
train_x_m = np.split(custom_feature_vecs,[3,8],axis=1)[0]
train_x_f = np.split(custom_feature_vecs,[4,7,8],axis=1)[1]
test_x_m = np.split(custom_feature_vecs,[3,4,8],axis=1)[1]
test_x_f = np.split(custom_feature_vecs,[7,8],axis=1)[1]
ctrain_x = np.reshape(np.concatenate((train_x_m,train_x_f),axis=1),[19*6,300,30])
ctest_x = np.reshape(np.concatenate((test_x_m,test_x_f),axis=1),[19*2,300,30])
ctrain_y = np.expand_dims(np.repeat([i for i in range(19)],6),axis=1)
ctest_y = np.expand_dims(np.repeat([i for i in range(19)],2),axis=1)
print(ctrain_x.shape, ctrain_y.shape, ctest_x.shape, ctest_y.shape)
# Out:
# (114, 300, 30) (114, 1) (38, 300, 30) (38, 1)

# %%
#hybrid feature splits
#pulling activity value one down to match indices
train_x_m = np.split(hybrid_vec,[3,8],axis=1)[0]
train_x_f = np.split(hybrid_vec,[4,7,8],axis=1)[1]
test_x_m = np.split(hybrid_vec,[3,4,8],axis=1)[1]
test_x_f = np.split(hybrid_vec,[7,8],axis=1)[1]
htrain_x = np.reshape(np.concatenate((train_x_m,train_x_f),axis=1),[19*6,300,30+45])
htest_x = np.reshape(np.concatenate((test_x_m,test_x_f),axis=1),[19*2,300,30+45])
htrain_y = np.expand_dims(np.repeat([i for i in range(19)],6),axis=1)
htest_y = np.expand_dims(np.repeat([i for i in range(19)],2),axis=1)
print(htrain_x.shape, htrain_y.shape, htest_x.shape, htest_y.shape)
# Out:
# (114, 300, 75) (114, 1) (38, 300, 75) (38, 1)

# %% [markdown]
# ### Classification Models
# Once past we've got our training and test sets ready, we can start implementing various classification models to the dataset. While building the learning models we first use each of our previously generated training and test pairs. Especially in the case of neural networks, we first try out the small test set to get an approximation of the model complexity and training time. After some experiments it was realized the hybrid training-test pair resulted in the best accuracy results without having any major impact on the training times.
#
# #### Bernoulli Naive Bayes
# The Bernoulli Naive Bayes model was the first to give us near accurate results, with a training accuracy of 99% and an accuracy of 76.3% on the test set.
# After Assessing the basic metrics, we plot a confusion matrix to get an idea of which activities were misclassified and also notice the relations between the pairs of activities which were confused with each other.

# %%
# fit a Naive Bayes bmodel to the data
bmodel = BernoulliNB()
bmodel.fit(htrain_x.reshape([114, 300*75]), htrain_y.reshape(htrain_y.shape[0],))
#print(bmodel)

# make predictions
expected = htrain_y.reshape(htrain_y.shape[0],)
predicted = bmodel.predict(htrain_x.reshape([114, 300*75]))
# summarize the fit of the bmodel
print("Training Accuracy:",metrics.accuracy_score(expected, predicted))
#print(metrics.confusion_matrix(expected, predicted))
plt.figure(figsize=[15,5])
plt.subplot(121)
sn.heatmap(metrics.confusion_matrix(expected, predicted))

expected = htest_y.reshape(htest_y.shape[0],)
predicted = bmodel.predict(htest_x.reshape([38, 300*75]))
# summarize the fit of the bmodel
print("Test Accuracy:",metrics.accuracy_score(expected, predicted))
#print(metrics.confusion_matrix(expected, predicted))
plt.subplot(122)
sn.heatmap(metrics.confusion_matrix(expected, predicted))
# Out:
# Training Accuracy: 0.991228070175
# Test Accuracy: 0.763157894737

# %% [markdown]
# ### Recurrent Neural Networks
#
# The first intuition was to test out the different variants of reccurent neural networks on our dataset due to the sequence learning nature of the same.<br>
# The initial tests involved the use of LSTM layers which, while more accurate than traditional RNN layers which suffered from vanishing/exploding gradient issues, were rather time consuming on our larger training sets.<br>
# The solution was to replace the LSTM layers with Gated Recurrent Units with proved to be just as accurate along with a significantly shorter training time, this was because of the simpler mechanism of GRU based layers.<br>
# Adding dropout layers also helped in significantly reducing the training time.<br>
# After a long while of hyperparameter tuning, we finally defined the following structure to be the most effecient option for our Sequential neural networks:
# * LSTM/GRU Layer: 128 neurons, returns sequences.
# * Dropout Layer: 40%
# * LSTM/GRU Layer: 64 neurons
# * Dropout Layer: 20%
# * Logits/Dense/Fully Connected layer: 19 neurons
# * Softmax Activation Layer - Output
# <br>
# We used the loss function: sparse categorical cross-entropy, which is slightly different from traditional categorical cross entropy as it does not need one hot coded label data.
# <br>
# We tested 3 optimizers with our model which included SGD, Adam, and RMSProp. While SGD's performance wasn't up to the mark, rmsprop and adam were provided close results. Adam proved to be the best optimizer for this problem, with short epoch processing time, fast descent and a top 3 accuracy close to 97% within 128 epochs @ 64 batch size.
# <br>
# We also noticed that adding activation layers(relu/sigmoid) after the lstm/gru layers results in decreased accuracy.

# %% [markdown]
# #### Defining the top 3 accuracy metric

# %%
import functools
top3_acc = functools.partial(keras.metrics.sparse_top_k_categorical_accuracy, k=3)

top3_acc.__name__ = 'top3_acc'

# %% [markdown]
# #### Standard Gradient Descent:
# The first experiment involved the use of sgd optimizer which resulted in the following final metrics:
# <br><br>Training Loss: 0.775403763119
# <br>Training Accuracy: 94.7368421053 %
# <br>Training Top 3 Accuracy: 100.0 %
# <br>Test loss: 1.37674241631
# <br>Test accuracy: 63.1578947368 %
# <br>Training Top 3 Accuracy: 84.2105263158 %
# <br>Approximate training time: 9 minutes

# %%
model_test = Sequential()
model_test.add(GRU(128, input_shape=(htrain_x.shape[1], htrain_x.shape[2]),return_sequences=True))
model_test.add(Dropout(0.4))
model_test.add(GRU(64, input_shape=(htrain_x.shape[1], htrain_x.shape[2])))
model_test.add(Dropout(0.2))
model_test.add(Dense(19))
model_test.add(Activation('softmax'))
model_test.compile(loss='sparse_categorical_crossentropy',
                  optimizer='sgd',
                  metrics=['accuracy', top3_acc])

history_test_sgd = model_test.fit(htrain_x, htrain_y, epochs=128, batch_size=64, validation_data=(htest_x, htest_y), verbose=2, shuffle=True)
# Out:
# Train on 114 samples, validate on 38 samples
# Epoch 1/128
# 7s - loss: 2.9938 - acc: 0.0614 - top3_acc: 0.2456 - val_loss: 3.1006 - val_acc: 0.0263 - val_top3_acc: 0.1579
# Epoch 2/128
# 4s - loss: 2.9566 - acc: 0.0789 - top3_acc: 0.2105 - val_loss: 3.0302 - val_acc: 0.0526 - val_top3_acc: 0.1579
# Epoch 3/128
# 4s - loss: 2.9510 - acc: 0.0614 - top3_acc: 0.1842 - val_loss: 2.9474 - val_acc: 0.0526 - val_top3_acc: 0.2105
# Epoch 4/128
# 4s - loss: 2.8638 - acc: 0.0263 - top3_acc: 0.2544 - val_loss: 2.8779 - val_acc: 0.0526 - val_top3_acc: 0.2895
# Epoch 5/128
# 4s - loss: 2.8159 - acc: 0.0789 - top3_acc: 0.2632 - val_loss: 2.8113 - val_acc: 0.1842 - val_top3_acc: 0.3158
# Epoch 6/128
# 4s - loss: 2.6992 - acc: 0.1667 - top3_acc: 0.3947 - val_loss: 2.7670 - val_acc: 0.2105 - val_top3_acc: 0.3684
# Epoch 7/128
# 4s - loss: 2.6290 - acc: 0.1754 - top3_acc: 0.4298 - val_loss: 2.7351 - val_acc: 0.1842 - val_top3_acc: 0.4474
# Epoch 8/128
# 4s - loss: 2.6842 - acc: 0.1316 - top3_acc: 0.3860 - val_loss: 2.6840 - val_acc: 0.2632 - val_top3_acc: 0.5000
# Epoch 9/128
# 4s - loss: 2.5835 - acc: 0.1754 - top3_acc: 0.4649 - val_loss: 2.6482 - val_acc: 0.2368 - val_top3_acc: 0.5000
# Epoch 10/128
# 4s - loss: 2.4717 - acc: 0.2368 - top3_acc: 0.5439 - val_loss: 2.6228 - val_acc: 0.2632 - val_top3_acc: 0.5263
# Epoch 11/128
# 4s - loss: 2.4904 - acc: 0.2105 - top3_acc: 0.5526 - val_loss: 2.5973 - val_acc: 0.2895 - val_top3_acc: 0.5263
# Epoch 12/128
# 4s - loss: 2.4302 - acc: 0.2807 - top3_acc: 0.6140 - val_loss: 2.5688 - val_acc: 0.3158 - val_top3_acc: 0.5526
# Epoch 13/128
# 4s - loss: 2.4916 - acc: 0.2456 - top3_acc: 0.5263 - val_loss: 2.5363 - val_acc: 0.3158 - val_top3_acc: 0.5526
# Epoch 14/128
# 4s - loss: 2.3954 - acc: 0.3333 - top3_acc: 0.5789 - val_loss: 2.5020 - val_acc: 0.3158 - val_top3_acc: 0.5526
# Epoch 15/128
# 4s - loss: 2.3345 - acc: 0.3596 - top3_acc: 0.6316 - val_loss: 2.4811 - val_acc: 0.3158 - val_top3_acc: 0.5526
# Epoch 16/128
# 4s - loss: 2.3311 - acc: 0.3070 - top3_acc: 0.6140 - val_loss: 2.4489 - val_acc: 0.2895 - val_top3_acc: 0.5526
# Epoch 17/128
# 4s - loss: 2.2179 - acc: 0.3772 - top3_acc: 0.6667 - val_loss: 2.4188 - val_acc: 0.3421 - val_top3_acc: 0.5526
# Epoch 18/128
# 4s - loss: 2.3327 - acc: 0.3509 - top3_acc: 0.6140 - val_loss: 2.3886 - val_acc: 0.3684 - val_top3_acc: 0.5789
# Epoch 19/128
# 4s - loss: 2.2820 - acc: 0.3684 - top3_acc: 0.6316 - val_loss: 2.3688 - val_acc: 0.3421 - val_top3_acc: 0.6053
# Epoch 20/128
# 4s - loss: 2.1990 - acc: 0.4123 - top3_acc: 0.6930 - val_loss: 2.3478 - val_acc: 0.3158 - val_top3_acc: 0.6053
# Epoch 21/128
# 4s - loss: 2.1861 - acc: 0.4474 - top3_acc: 0.7193 - val_loss: 2.3250 - val_acc: 0.3421 - val_top3_acc: 0.6053
# Epoch 22/128
# 4s - loss: 2.1508 - acc: 0.4298 - top3_acc: 0.7193 - val_loss: 2.2928 - val_acc: 0.3947 - val_top3_acc: 0.6053
# Epoch 23/128
# 4s - loss: 2.1023 - acc: 0.4825 - top3_acc: 0.7456 - val_loss: 2.2712 - val_acc: 0.4211 - val_top3_acc: 0.6053
# Epoch 24/128
# 4s - loss: 2.0962 - acc: 0.4737 - top3_acc: 0.7281 - val_loss: 2.2496 - val_acc: 0.4474 - val_top3_acc: 0.6053
# Epoch 25/128
# 4s - loss: 2.1262 - acc: 0.4211 - top3_acc: 0.6667 - val_loss: 2.2295 - val_acc: 0.4211 - val_top3_acc: 0.6579
# Epoch 26/128
# 4s - loss: 2.0681 - acc: 0.4649 - top3_acc: 0.7105 - val_loss: 2.2090 - val_acc: 0.4211 - val_top3_acc: 0.6316
# Epoch 27/128
# 4s - loss: 2.0498 - acc: 0.4561 - top3_acc: 0.7456 - val_loss: 2.1988 - val_acc: 0.3947 - val_top3_acc: 0.6316
# Epoch 28/128
# 4s - loss: 1.9850 - acc: 0.5175 - top3_acc: 0.7456 - val_loss: 2.1817 - val_acc: 0.4737 - val_top3_acc: 0.6316
# Epoch 29/128
# 4s - loss: 1.9763 - acc: 0.5088 - top3_acc: 0.7719 - val_loss: 2.1654 - val_acc: 0.4474 - val_top3_acc: 0.6579
# Epoch 30/128
# 4s - loss: 2.0138 - acc: 0.5088 - top3_acc: 0.7719 - val_loss: 2.1476 - val_acc: 0.4211 - val_top3_acc: 0.6316
# Epoch 31/128
# 4s - loss: 1.8987 - acc: 0.5877 - top3_acc: 0.8070 - val_loss: 2.1222 - val_acc: 0.4737 - val_top3_acc: 0.6316
# Epoch 32/128
# 4s - loss: 1.9295 - acc: 0.5614 - top3_acc: 0.7544 - val_loss: 2.1059 - val_acc: 0.4737 - val_top3_acc: 0.6579
# Epoch 33/128
# 4s - loss: 1.9087 - acc: 0.5088 - top3_acc: 0.7982 - val_loss: 2.0894 - val_acc: 0.4737 - val_top3_acc: 0.6316
# Epoch 34/128
# 4s - loss: 1.8602 - acc: 0.5526 - top3_acc: 0.7807 - val_loss: 2.0804 - val_acc: 0.5000 - val_top3_acc: 0.6579
# Epoch 35/128
# 4s - loss: 1.8567 - acc: 0.5088 - top3_acc: 0.8158 - val_loss: 2.0631 - val_acc: 0.4737 - val_top3_acc: 0.6579
# Epoch 36/128
# 4s - loss: 1.8636 - acc: 0.5263 - top3_acc: 0.8246 - val_loss: 2.0484 - val_acc: 0.4737 - val_top3_acc: 0.6579
# Epoch 37/128
# 4s - loss: 1.9026 - acc: 0.5175 - top3_acc: 0.7456 - val_loss: 2.0463 - val_acc: 0.4474 - val_top3_acc: 0.6579
# Epoch 38/128
# 4s - loss: 1.8367 - acc: 0.5088 - top3_acc: 0.8158 - val_loss: 2.0376 - val_acc: 0.4737 - val_top3_acc: 0.6579
# Epoch 39/128
# 4s - loss: 1.8202 - acc: 0.5439 - top3_acc: 0.8333 - val_loss: 2.0228 - val_acc: 0.5000 - val_top3_acc: 0.6579
# Epoch 40/128
# 4s - loss: 1.7681 - acc: 0.5702 - top3_acc: 0.8246 - val_loss: 1.9966 - val_acc: 0.4737 - val_top3_acc: 0.6842
# Epoch 41/128
# 4s - loss: 1.7877 - acc: 0.5614 - top3_acc: 0.8246 - val_loss: 1.9892 - val_acc: 0.5000 - val_top3_acc: 0.6316
# Epoch 42/128
# 4s - loss: 1.7968 - acc: 0.5000 - top3_acc: 0.8158 - val_loss: 1.9689 - val_acc: 0.5263 - val_top3_acc: 0.6842
# Epoch 43/128
# 4s - loss: 1.7099 - acc: 0.6404 - top3_acc: 0.8860 - val_loss: 1.9525 - val_acc: 0.4737 - val_top3_acc: 0.6842
# Epoch 44/128
# 4s - loss: 1.7617 - acc: 0.5789 - top3_acc: 0.8333 - val_loss: 1.9500 - val_acc: 0.4737 - val_top3_acc: 0.6579
# Epoch 45/128
# 4s - loss: 1.7385 - acc: 0.5439 - top3_acc: 0.8158 - val_loss: 1.9358 - val_acc: 0.5000 - val_top3_acc: 0.7105
# Epoch 46/128
# 5s - loss: 1.7600 - acc: 0.5526 - top3_acc: 0.8333 - val_loss: 1.9257 - val_acc: 0.4737 - val_top3_acc: 0.7368
# Epoch 47/128
# 4s - loss: 1.6149 - acc: 0.6053 - top3_acc: 0.9035 - val_loss: 1.9186 - val_acc: 0.4737 - val_top3_acc: 0.6579
# Epoch 48/128
# 4s - loss: 1.7220 - acc: 0.6053 - top3_acc: 0.8596 - val_loss: 1.9126 - val_acc: 0.5000 - val_top3_acc: 0.6842
# Epoch 49/128
# 4s - loss: 1.6561 - acc: 0.6316 - top3_acc: 0.8246 - val_loss: 1.9003 - val_acc: 0.5000 - val_top3_acc: 0.6579
# Epoch 50/128
# 4s - loss: 1.6642 - acc: 0.6579 - top3_acc: 0.8509 - val_loss: 1.8798 - val_acc: 0.5000 - val_top3_acc: 0.6842
# Epoch 51/128
# 4s - loss: 1.6562 - acc: 0.6842 - top3_acc: 0.8772 - val_loss: 1.8654 - val_acc: 0.4474 - val_top3_acc: 0.7632
# Epoch 52/128
# 4s - loss: 1.5805 - acc: 0.6754 - top3_acc: 0.8596 - val_loss: 1.8545 - val_acc: 0.4737 - val_top3_acc: 0.7895
# Epoch 53/128
# 4s - loss: 1.5911 - acc: 0.5965 - top3_acc: 0.8772 - val_loss: 1.8449 - val_acc: 0.4474 - val_top3_acc: 0.7895
# Epoch 54/128
# 4s - loss: 1.5859 - acc: 0.6491 - top3_acc: 0.9035 - val_loss: 1.8293 - val_acc: 0.4474 - val_top3_acc: 0.7632
# Epoch 55/128
# 4s - loss: 1.5705 - acc: 0.6228 - top3_acc: 0.8684 - val_loss: 1.8186 - val_acc: 0.4474 - val_top3_acc: 0.7632
# Epoch 56/128
# 4s - loss: 1.5757 - acc: 0.6053 - top3_acc: 0.8421 - val_loss: 1.8135 - val_acc: 0.4737 - val_top3_acc: 0.7632
# Epoch 57/128
# 4s - loss: 1.5188 - acc: 0.6754 - top3_acc: 0.8860 - val_loss: 1.8082 - val_acc: 0.4474 - val_top3_acc: 0.7895
# Epoch 58/128
# 4s - loss: 1.5774 - acc: 0.6053 - top3_acc: 0.8947 - val_loss: 1.7933 - val_acc: 0.4737 - val_top3_acc: 0.7895
# Epoch 59/128
# 4s - loss: 1.5412 - acc: 0.6491 - top3_acc: 0.8860 - val_loss: 1.7830 - val_acc: 0.4737 - val_top3_acc: 0.7368
# Epoch 60/128
# 4s - loss: 1.4975 - acc: 0.6754 - top3_acc: 0.8860 - val_loss: 1.7731 - val_acc: 0.4737 - val_top3_acc: 0.7368
# Epoch 61/128
# 4s - loss: 1.5050 - acc: 0.6228 - top3_acc: 0.8947 - val_loss: 1.7682 - val_acc: 0.5000 - val_top3_acc: 0.7895
# Epoch 62/128
# 4s - loss: 1.5142 - acc: 0.6754 - top3_acc: 0.8860 - val_loss: 1.7633 - val_acc: 0.5000 - val_top3_acc: 0.7632
# Epoch 63/128
# 4s - loss: 1.4574 - acc: 0.7018 - top3_acc: 0.9561 - val_loss: 1.7569 - val_acc: 0.5000 - val_top3_acc: 0.7895
# Epoch 64/128
# 4s - loss: 1.5422 - acc: 0.6316 - top3_acc: 0.8772 - val_loss: 1.7496 - val_acc: 0.5000 - val_top3_acc: 0.7632
# Epoch 65/128
# 4s - loss: 1.5081 - acc: 0.7193 - top3_acc: 0.8684 - val_loss: 1.7405 - val_acc: 0.5000 - val_top3_acc: 0.8158
# Epoch 66/128
# 4s - loss: 1.4146 - acc: 0.7281 - top3_acc: 0.8860 - val_loss: 1.7385 - val_acc: 0.4737 - val_top3_acc: 0.7895
# Epoch 67/128
# 4s - loss: 1.4255 - acc: 0.7193 - top3_acc: 0.9211 - val_loss: 1.7260 - val_acc: 0.5000 - val_top3_acc: 0.7895
# Epoch 68/128
# 4s - loss: 1.4324 - acc: 0.6667 - top3_acc: 0.9035 - val_loss: 1.7129 - val_acc: 0.5000 - val_top3_acc: 0.7895
# Epoch 69/128
# 4s - loss: 1.4506 - acc: 0.6754 - top3_acc: 0.9123 - val_loss: 1.7111 - val_acc: 0.5263 - val_top3_acc: 0.7895
# Epoch 70/128
# 4s - loss: 1.4688 - acc: 0.6404 - top3_acc: 0.8947 - val_loss: 1.7075 - val_acc: 0.5263 - val_top3_acc: 0.8158
# Epoch 71/128
# 4s - loss: 1.3987 - acc: 0.7719 - top3_acc: 0.9298 - val_loss: 1.6985 - val_acc: 0.5000 - val_top3_acc: 0.8421
# Epoch 72/128
# 4s - loss: 1.3851 - acc: 0.6667 - top3_acc: 0.9298 - val_loss: 1.6928 - val_acc: 0.5000 - val_top3_acc: 0.8421
# Epoch 73/128
# 4s - loss: 1.3898 - acc: 0.7193 - top3_acc: 0.9123 - val_loss: 1.6778 - val_acc: 0.5000 - val_top3_acc: 0.7895
# Epoch 74/128
# 4s - loss: 1.4013 - acc: 0.7193 - top3_acc: 0.9561 - val_loss: 1.6704 - val_acc: 0.5000 - val_top3_acc: 0.8158
# Epoch 75/128
# 4s - loss: 1.3790 - acc: 0.6491 - top3_acc: 0.9298 - val_loss: 1.6602 - val_acc: 0.5000 - val_top3_acc: 0.7895
# Epoch 76/128
# 4s - loss: 1.3986 - acc: 0.7018 - top3_acc: 0.8860 - val_loss: 1.6500 - val_acc: 0.5526 - val_top3_acc: 0.7895
# Epoch 77/128
# 4s - loss: 1.2935 - acc: 0.7632 - top3_acc: 0.9649 - val_loss: 1.6538 - val_acc: 0.5263 - val_top3_acc: 0.7895
# Epoch 78/128
# 4s - loss: 1.4000 - acc: 0.6930 - top3_acc: 0.8947 - val_loss: 1.6443 - val_acc: 0.5000 - val_top3_acc: 0.7895
# Epoch 79/128
# 4s - loss: 1.3257 - acc: 0.7368 - top3_acc: 0.9211 - val_loss: 1.6328 - val_acc: 0.5526 - val_top3_acc: 0.7895
# Epoch 80/128
# 4s - loss: 1.3167 - acc: 0.7193 - top3_acc: 0.9737 - val_loss: 1.6275 - val_acc: 0.5526 - val_top3_acc: 0.7895
# Epoch 81/128
# 4s - loss: 1.3538 - acc: 0.6667 - top3_acc: 0.9123 - val_loss: 1.6226 - val_acc: 0.5263 - val_top3_acc: 0.7895
# Epoch 82/128
# 4s - loss: 1.3327 - acc: 0.7018 - top3_acc: 0.9474 - val_loss: 1.6210 - val_acc: 0.5263 - val_top3_acc: 0.8158
# Epoch 83/128
# 4s - loss: 1.2900 - acc: 0.7281 - top3_acc: 0.9298 - val_loss: 1.5999 - val_acc: 0.5526 - val_top3_acc: 0.8421
# Epoch 84/128
# 4s - loss: 1.2425 - acc: 0.7982 - top3_acc: 0.9912 - val_loss: 1.5963 - val_acc: 0.5263 - val_top3_acc: 0.8421
# Epoch 85/128
# 4s - loss: 1.2725 - acc: 0.8070 - top3_acc: 0.9649 - val_loss: 1.5936 - val_acc: 0.5263 - val_top3_acc: 0.8421
# Epoch 86/128
# 4s - loss: 1.2683 - acc: 0.7368 - top3_acc: 0.8947 - val_loss: 1.5876 - val_acc: 0.5000 - val_top3_acc: 0.8421
# Epoch 87/128
# 5s - loss: 1.2424 - acc: 0.7895 - top3_acc: 0.9561 - val_loss: 1.5823 - val_acc: 0.5789 - val_top3_acc: 0.8421
# Epoch 88/128
# 4s - loss: 1.2826 - acc: 0.7368 - top3_acc: 0.9035 - val_loss: 1.5775 - val_acc: 0.5526 - val_top3_acc: 0.8421
# Epoch 89/128
# 5s - loss: 1.2472 - acc: 0.7719 - top3_acc: 0.9649 - val_loss: 1.5599 - val_acc: 0.6053 - val_top3_acc: 0.8421
# Epoch 90/128
# 4s - loss: 1.2586 - acc: 0.7632 - top3_acc: 0.9825 - val_loss: 1.5555 - val_acc: 0.5789 - val_top3_acc: 0.8421
# Epoch 91/128
# 5s - loss: 1.1783 - acc: 0.7807 - top3_acc: 0.9737 - val_loss: 1.5547 - val_acc: 0.5526 - val_top3_acc: 0.8421
# Epoch 92/128
# 4s - loss: 1.2893 - acc: 0.7105 - top3_acc: 0.9211 - val_loss: 1.5549 - val_acc: 0.5526 - val_top3_acc: 0.8421
# Epoch 93/128
# 4s - loss: 1.1888 - acc: 0.7895 - top3_acc: 0.9737 - val_loss: 1.5436 - val_acc: 0.5526 - val_top3_acc: 0.8421
# Epoch 94/128
# 4s - loss: 1.2326 - acc: 0.7544 - top3_acc: 0.9386 - val_loss: 1.5343 - val_acc: 0.5526 - val_top3_acc: 0.8421
# Epoch 95/128
# 4s - loss: 1.1880 - acc: 0.7632 - top3_acc: 0.9649 - val_loss: 1.5251 - val_acc: 0.6053 - val_top3_acc: 0.8421
# Epoch 96/128
# 4s - loss: 1.2040 - acc: 0.7719 - top3_acc: 0.9649 - val_loss: 1.5259 - val_acc: 0.6053 - val_top3_acc: 0.8421
# Epoch 97/128
# 4s - loss: 1.1312 - acc: 0.8333 - top3_acc: 0.9912 - val_loss: 1.5238 - val_acc: 0.5789 - val_top3_acc: 0.8158
# Epoch 98/128
# 4s - loss: 1.1650 - acc: 0.7982 - top3_acc: 0.9737 - val_loss: 1.5136 - val_acc: 0.5789 - val_top3_acc: 0.8421
# Epoch 99/128
# 4s - loss: 1.1365 - acc: 0.8158 - top3_acc: 0.9561 - val_loss: 1.5054 - val_acc: 0.5789 - val_top3_acc: 0.8421
# Epoch 100/128
# 4s - loss: 1.1930 - acc: 0.7895 - top3_acc: 0.9386 - val_loss: 1.5085 - val_acc: 0.5789 - val_top3_acc: 0.8421
# Epoch 101/128
# 4s - loss: 1.1496 - acc: 0.7982 - top3_acc: 0.9561 - val_loss: 1.5021 - val_acc: 0.6316 - val_top3_acc: 0.8421
# Epoch 102/128
# 4s - loss: 1.1229 - acc: 0.8070 - top3_acc: 0.9649 - val_loss: 1.5024 - val_acc: 0.5789 - val_top3_acc: 0.8421
# Epoch 103/128
# 4s - loss: 1.1140 - acc: 0.8246 - top3_acc: 0.9912 - val_loss: 1.4895 - val_acc: 0.5789 - val_top3_acc: 0.8421
# Epoch 104/128
# 4s - loss: 1.1912 - acc: 0.7895 - top3_acc: 0.9386 - val_loss: 1.4851 - val_acc: 0.6053 - val_top3_acc: 0.8421
# Epoch 105/128
# 4s - loss: 1.1523 - acc: 0.7368 - top3_acc: 0.9561 - val_loss: 1.4717 - val_acc: 0.6316 - val_top3_acc: 0.8421
# Epoch 106/128
# 4s - loss: 1.1619 - acc: 0.7632 - top3_acc: 0.9561 - val_loss: 1.4657 - val_acc: 0.5789 - val_top3_acc: 0.8421
# Epoch 107/128
# 4s - loss: 1.1093 - acc: 0.7807 - top3_acc: 0.9737 - val_loss: 1.4640 - val_acc: 0.5789 - val_top3_acc: 0.8421
# Epoch 108/128
# 4s - loss: 1.1311 - acc: 0.7544 - top3_acc: 0.9649 - val_loss: 1.4489 - val_acc: 0.6053 - val_top3_acc: 0.8421
# Epoch 109/128
# 4s - loss: 1.1034 - acc: 0.7895 - top3_acc: 0.9737 - val_loss: 1.4558 - val_acc: 0.6316 - val_top3_acc: 0.8421
# Epoch 110/128
# 4s - loss: 1.1112 - acc: 0.7807 - top3_acc: 0.9649 - val_loss: 1.4459 - val_acc: 0.6316 - val_top3_acc: 0.8421
# Epoch 111/128
# 4s - loss: 1.0716 - acc: 0.8158 - top3_acc: 0.9737 - val_loss: 1.4472 - val_acc: 0.6053 - val_top3_acc: 0.8421
# Epoch 112/128
# 4s - loss: 1.0531 - acc: 0.8158 - top3_acc: 0.9649 - val_loss: 1.4345 - val_acc: 0.6053 - val_top3_acc: 0.8421
# Epoch 113/128
# 4s - loss: 1.1085 - acc: 0.7719 - top3_acc: 0.9737 - val_loss: 1.4391 - val_acc: 0.5789 - val_top3_acc: 0.8158
# Epoch 114/128
# 4s - loss: 1.0879 - acc: 0.7982 - top3_acc: 0.9649 - val_loss: 1.4294 - val_acc: 0.5789 - val_top3_acc: 0.8421
# Epoch 115/128
# 4s - loss: 1.0348 - acc: 0.8158 - top3_acc: 0.9825 - val_loss: 1.4257 - val_acc: 0.5789 - val_top3_acc: 0.8421
# Epoch 116/128
# 4s - loss: 1.0176 - acc: 0.8860 - top3_acc: 0.9737 - val_loss: 1.4195 - val_acc: 0.6053 - val_top3_acc: 0.8421
# Epoch 117/128
# 4s - loss: 1.0068 - acc: 0.8333 - top3_acc: 0.9825 - val_loss: 1.4145 - val_acc: 0.6579 - val_top3_acc: 0.8421
# Epoch 118/128
# 4s - loss: 1.0355 - acc: 0.8246 - top3_acc: 0.9737 - val_loss: 1.4106 - val_acc: 0.6579 - val_top3_acc: 0.8421
# Epoch 119/128
# 4s - loss: 1.0676 - acc: 0.7982 - top3_acc: 1.0000 - val_loss: 1.4063 - val_acc: 0.6316 - val_top3_acc: 0.8421
# Epoch 120/128
# 4s - loss: 1.0371 - acc: 0.8333 - top3_acc: 1.0000 - val_loss: 1.4027 - val_acc: 0.6579 - val_top3_acc: 0.8421
# Epoch 121/128
# 4s - loss: 1.0386 - acc: 0.8333 - top3_acc: 0.9825 - val_loss: 1.3997 - val_acc: 0.6579 - val_top3_acc: 0.8421
# Epoch 122/128
# 4s - loss: 0.9976 - acc: 0.8772 - top3_acc: 0.9912 - val_loss: 1.3972 - val_acc: 0.6579 - val_top3_acc: 0.8421
# Epoch 123/128
# 4s - loss: 1.0372 - acc: 0.7982 - top3_acc: 0.9912 - val_loss: 1.3968 - val_acc: 0.6579 - val_top3_acc: 0.8421
# Epoch 124/128
# 4s - loss: 0.9778 - acc: 0.8684 - top3_acc: 0.9912 - val_loss: 1.3889 - val_acc: 0.6316 - val_top3_acc: 0.8684
# Epoch 125/128
# 4s - loss: 1.0431 - acc: 0.8070 - top3_acc: 0.9649 - val_loss: 1.3886 - val_acc: 0.6579 - val_top3_acc: 0.8684
# Epoch 126/128
# 4s - loss: 1.0173 - acc: 0.8596 - top3_acc: 0.9825 - val_loss: 1.3811 - val_acc: 0.6053 - val_top3_acc: 0.8421
# Epoch 127/128
# 4s - loss: 0.9656 - acc: 0.8860 - top3_acc: 0.9737 - val_loss: 1.3820 - val_acc: 0.6053 - val_top3_acc: 0.8684
# Epoch 128/128
# 4s - loss: 0.9912 - acc: 0.8509 - top3_acc: 0.9649 - val_loss: 1.3767 - val_acc: 0.6316 - val_top3_acc: 0.8421

# %%
scores = model_test.evaluate(htrain_x, htrain_y, verbose=1)
print('Training Loss:', scores[0])
print('Training Accuracy:', scores[1]*100,'%')
print('Training Top 3 Accuracy:', scores[2]*100,'%')
scores = model_test.evaluate(htest_x, htest_y, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1]*100,'%')
print('Training Top 3 Accuracy:', scores[2]*100,'%')
# Out:
# 114/114 [==============================] - 1s
# Training Loss: 0.775403763119
# Training Accuracy: 94.7368421053 %
# Training Top 3 Accuracy: 100.0 %
# 38/38 [==============================] - 0s
# Test loss: 1.37674241631
# Test accuracy: 63.1578947368 %
# Training Top 3 Accuracy: 84.2105263158 %

# %% [markdown]
# #### RMSPROP
# Using the rmsprop optimizer resulted in a better performance with the following metrics:
# <br><br>Training Loss: 0.139823080776
# <br>Training Accuracy: 96.4912280702 %
# <br>Training Top 3 Accuracy: 100.0 %
# <br>Test loss: 1.49589552377
# <br>Test accuracy: 65.7894736842 %
# <br>Training Top 3 Accuracy: 92.1052631579 %
# <br>Approximate Training Time: 9 minutes

# %%
model_test = Sequential()
model_test.add(GRU(128, input_shape=(htrain_x.shape[1], htrain_x.shape[2]),return_sequences=True,activation='relu'))
model_test.add(Dropout(0.4))
model_test.add(GRU(64, input_shape=(htrain_x.shape[1], htrain_x.shape[2]),activation='relu'))
model_test.add(Dropout(0.2))
model_test.add(Dense(19))
model_test.add(Activation('softmax'))
model_test.compile(loss='sparse_categorical_crossentropy',
                  optimizer='rmsprop',
                  metrics=['accuracy', top3_acc])

# %%
history_test_rms = model_test.fit(htrain_x, htrain_y, epochs=128, batch_size=64, validation_data=(htest_x, htest_y), verbose=2, shuffle=True)
# Out:
# Train on 114 samples, validate on 38 samples
# Epoch 1/128
# 6s - loss: 5.3713 - acc: 0.0351 - top3_acc: 0.1404 - val_loss: 3.0464 - val_acc: 0.1053 - val_top3_acc: 0.1842
# Epoch 2/128
# 4s - loss: 3.8394 - acc: 0.0789 - top3_acc: 0.2544 - val_loss: 2.8678 - val_acc: 0.0789 - val_top3_acc: 0.2368
# Epoch 3/128
# 4s - loss: 3.5577 - acc: 0.0789 - top3_acc: 0.2193 - val_loss: 2.8996 - val_acc: 0.1053 - val_top3_acc: 0.3158
# Epoch 4/128
# 4s - loss: 3.5516 - acc: 0.1579 - top3_acc: 0.3070 - val_loss: 2.8644 - val_acc: 0.1316 - val_top3_acc: 0.2895
# Epoch 5/128
# 4s - loss: 3.3018 - acc: 0.1754 - top3_acc: 0.3684 - val_loss: 2.7232 - val_acc: 0.1842 - val_top3_acc: 0.3684
# Epoch 6/128
# 4s - loss: 3.0779 - acc: 0.1491 - top3_acc: 0.3246 - val_loss: 2.6551 - val_acc: 0.1842 - val_top3_acc: 0.5000
# Epoch 7/128
# 4s - loss: 2.8446 - acc: 0.1579 - top3_acc: 0.3421 - val_loss: 2.5296 - val_acc: 0.2632 - val_top3_acc: 0.5000
# Epoch 8/128
# 4s - loss: 2.8437 - acc: 0.1930 - top3_acc: 0.3509 - val_loss: 2.4476 - val_acc: 0.2632 - val_top3_acc: 0.6053
# Epoch 9/128
# 4s - loss: 2.7046 - acc: 0.2193 - top3_acc: 0.4474 - val_loss: 2.3663 - val_acc: 0.2632 - val_top3_acc: 0.6579
# Epoch 10/128
# 4s - loss: 2.8069 - acc: 0.2105 - top3_acc: 0.4211 - val_loss: 2.2828 - val_acc: 0.2895 - val_top3_acc: 0.5526
# Epoch 11/128
# 4s - loss: 2.6510 - acc: 0.2632 - top3_acc: 0.5000 - val_loss: 2.1839 - val_acc: 0.2632 - val_top3_acc: 0.6053
# Epoch 12/128
# 4s - loss: 2.3679 - acc: 0.3070 - top3_acc: 0.5439 - val_loss: 2.1142 - val_acc: 0.3421 - val_top3_acc: 0.6053
# Epoch 13/128
# 4s - loss: 2.5187 - acc: 0.2982 - top3_acc: 0.5175 - val_loss: 2.0917 - val_acc: 0.3684 - val_top3_acc: 0.6316
# Epoch 14/128
# 4s - loss: 2.3443 - acc: 0.3070 - top3_acc: 0.5526 - val_loss: 2.0331 - val_acc: 0.3947 - val_top3_acc: 0.7105
# Epoch 15/128
# 4s - loss: 2.1201 - acc: 0.3421 - top3_acc: 0.5789 - val_loss: 1.9829 - val_acc: 0.4474 - val_top3_acc: 0.7105
# Epoch 16/128
# 4s - loss: 2.3723 - acc: 0.3421 - top3_acc: 0.6404 - val_loss: 1.9826 - val_acc: 0.3684 - val_top3_acc: 0.7105
# Epoch 17/128
# 4s - loss: 2.0340 - acc: 0.3772 - top3_acc: 0.6579 - val_loss: 1.9061 - val_acc: 0.3947 - val_top3_acc: 0.7368
# Epoch 18/128
# 4s - loss: 2.0389 - acc: 0.3947 - top3_acc: 0.6316 - val_loss: 1.9281 - val_acc: 0.4737 - val_top3_acc: 0.7105
# Epoch 19/128
# 4s - loss: 1.9256 - acc: 0.3947 - top3_acc: 0.6842 - val_loss: 1.8221 - val_acc: 0.5000 - val_top3_acc: 0.8158
# Epoch 20/128
# 4s - loss: 1.9205 - acc: 0.5088 - top3_acc: 0.7456 - val_loss: 1.8658 - val_acc: 0.4474 - val_top3_acc: 0.8158
# Epoch 21/128
# 4s - loss: 1.7954 - acc: 0.4561 - top3_acc: 0.7105 - val_loss: 1.7752 - val_acc: 0.4474 - val_top3_acc: 0.7368
# Epoch 22/128
# 4s - loss: 1.6991 - acc: 0.5088 - top3_acc: 0.7193 - val_loss: 1.6355 - val_acc: 0.5526 - val_top3_acc: 0.7632
# Epoch 23/128
# 4s - loss: 1.7777 - acc: 0.4912 - top3_acc: 0.7281 - val_loss: 1.5854 - val_acc: 0.5526 - val_top3_acc: 0.8684
# Epoch 24/128
# 4s - loss: 1.8765 - acc: 0.4298 - top3_acc: 0.7544 - val_loss: 1.5805 - val_acc: 0.5263 - val_top3_acc: 0.8158
# Epoch 25/128
# 4s - loss: 1.6769 - acc: 0.5000 - top3_acc: 0.7719 - val_loss: 1.4706 - val_acc: 0.6053 - val_top3_acc: 0.8421
# Epoch 26/128
# 4s - loss: 1.6102 - acc: 0.5877 - top3_acc: 0.8509 - val_loss: 1.4802 - val_acc: 0.5526 - val_top3_acc: 0.8421
# Epoch 27/128
# 4s - loss: 1.5148 - acc: 0.5351 - top3_acc: 0.8333 - val_loss: 1.5029 - val_acc: 0.5526 - val_top3_acc: 0.8158
# Epoch 28/128
# 4s - loss: 1.5972 - acc: 0.5263 - top3_acc: 0.7807 - val_loss: 1.5478 - val_acc: 0.5789 - val_top3_acc: 0.7632
# Epoch 29/128
# 4s - loss: 1.4925 - acc: 0.5702 - top3_acc: 0.7895 - val_loss: 1.4467 - val_acc: 0.5789 - val_top3_acc: 0.7895
# Epoch 30/128
# 4s - loss: 1.3010 - acc: 0.6404 - top3_acc: 0.8509 - val_loss: 1.3136 - val_acc: 0.6316 - val_top3_acc: 0.8684
# Epoch 31/128
# 4s - loss: 1.3022 - acc: 0.5965 - top3_acc: 0.8509 - val_loss: 1.2548 - val_acc: 0.6579 - val_top3_acc: 0.8947
# Epoch 32/128
# 4s - loss: 1.2155 - acc: 0.5877 - top3_acc: 0.8333 - val_loss: 1.2429 - val_acc: 0.6842 - val_top3_acc: 0.8158
# Epoch 33/128
# 4s - loss: 1.0416 - acc: 0.6842 - top3_acc: 0.8860 - val_loss: 1.2051 - val_acc: 0.6053 - val_top3_acc: 0.8421
# Epoch 34/128
# 4s - loss: 1.2151 - acc: 0.6316 - top3_acc: 0.8947 - val_loss: 1.2337 - val_acc: 0.5526 - val_top3_acc: 0.8684
# Epoch 35/128
# 4s - loss: 1.1296 - acc: 0.5965 - top3_acc: 0.8860 - val_loss: 1.2743 - val_acc: 0.5263 - val_top3_acc: 0.8158
# Epoch 36/128
# 4s - loss: 1.2371 - acc: 0.6228 - top3_acc: 0.8596 - val_loss: 1.4005 - val_acc: 0.5263 - val_top3_acc: 0.8684
# Epoch 37/128
# 4s - loss: 1.1653 - acc: 0.7105 - top3_acc: 0.8860 - val_loss: 1.3684 - val_acc: 0.5526 - val_top3_acc: 0.8421
# Epoch 38/128
# 4s - loss: 0.8970 - acc: 0.6930 - top3_acc: 0.9474 - val_loss: 1.3176 - val_acc: 0.5000 - val_top3_acc: 0.8158
# Epoch 39/128
# 4s - loss: 1.0061 - acc: 0.6579 - top3_acc: 0.9298 - val_loss: 1.3007 - val_acc: 0.5526 - val_top3_acc: 0.8684
# Epoch 40/128
# 4s - loss: 0.9026 - acc: 0.7632 - top3_acc: 0.9298 - val_loss: 1.3915 - val_acc: 0.5263 - val_top3_acc: 0.8158
# Epoch 41/128
# 4s - loss: 0.7585 - acc: 0.7895 - top3_acc: 0.9386 - val_loss: 1.3443 - val_acc: 0.5526 - val_top3_acc: 0.8684
# Epoch 42/128
# 4s - loss: 1.0151 - acc: 0.7105 - top3_acc: 0.8772 - val_loss: 1.1042 - val_acc: 0.5526 - val_top3_acc: 0.8684
# Epoch 43/128
# 4s - loss: 0.7943 - acc: 0.7281 - top3_acc: 0.9211 - val_loss: 1.1132 - val_acc: 0.6579 - val_top3_acc: 0.8421
# Epoch 44/128
# 4s - loss: 0.8085 - acc: 0.7456 - top3_acc: 0.8947 - val_loss: 1.0749 - val_acc: 0.6316 - val_top3_acc: 0.8684
# Epoch 45/128
# 4s - loss: 0.9187 - acc: 0.7193 - top3_acc: 0.8772 - val_loss: 1.1321 - val_acc: 0.6316 - val_top3_acc: 0.9211
# Epoch 46/128
# 4s - loss: 0.7619 - acc: 0.7456 - top3_acc: 0.9123 - val_loss: 1.1125 - val_acc: 0.5789 - val_top3_acc: 0.8684
# Epoch 47/128
# 4s - loss: 0.7681 - acc: 0.7544 - top3_acc: 0.9211 - val_loss: 0.9908 - val_acc: 0.6053 - val_top3_acc: 0.8947
# Epoch 48/128
# 4s - loss: 0.7215 - acc: 0.7544 - top3_acc: 0.9649 - val_loss: 0.8823 - val_acc: 0.7105 - val_top3_acc: 0.9211
# Epoch 49/128
# 4s - loss: 0.8376 - acc: 0.7632 - top3_acc: 0.9298 - val_loss: 1.0884 - val_acc: 0.6579 - val_top3_acc: 0.9474
# Epoch 50/128
# 4s - loss: 0.8254 - acc: 0.7193 - top3_acc: 0.9561 - val_loss: 1.1300 - val_acc: 0.6842 - val_top3_acc: 0.9211
# Epoch 51/128
# 4s - loss: 0.7590 - acc: 0.7193 - top3_acc: 0.9737 - val_loss: 1.0624 - val_acc: 0.6579 - val_top3_acc: 0.8947
# Epoch 52/128
# 4s - loss: 0.7918 - acc: 0.7632 - top3_acc: 0.9386 - val_loss: 1.0803 - val_acc: 0.6316 - val_top3_acc: 0.8684
# Epoch 53/128
# 4s - loss: 0.6738 - acc: 0.7895 - top3_acc: 0.9737 - val_loss: 1.1291 - val_acc: 0.5263 - val_top3_acc: 0.9211
# Epoch 54/128
# 4s - loss: 0.6405 - acc: 0.8070 - top3_acc: 0.9474 - val_loss: 1.1175 - val_acc: 0.6053 - val_top3_acc: 0.9211
# Epoch 55/128
# 4s - loss: 0.6696 - acc: 0.7895 - top3_acc: 0.9912 - val_loss: 0.9527 - val_acc: 0.6579 - val_top3_acc: 0.8947
# Epoch 56/128
# 4s - loss: 0.5914 - acc: 0.7982 - top3_acc: 0.9649 - val_loss: 1.1863 - val_acc: 0.5789 - val_top3_acc: 0.8421
# Epoch 57/128
# 4s - loss: 0.5237 - acc: 0.8070 - top3_acc: 0.9737 - val_loss: 1.0742 - val_acc: 0.6842 - val_top3_acc: 0.8947
# Epoch 58/128
# 4s - loss: 0.6029 - acc: 0.7368 - top3_acc: 0.9737 - val_loss: 1.1115 - val_acc: 0.6579 - val_top3_acc: 0.8684
# Epoch 59/128
# 4s - loss: 0.5008 - acc: 0.8421 - top3_acc: 0.9912 - val_loss: 1.1001 - val_acc: 0.6579 - val_top3_acc: 0.8684
# Epoch 60/128
# 4s - loss: 0.5779 - acc: 0.8596 - top3_acc: 0.9825 - val_loss: 1.0921 - val_acc: 0.6842 - val_top3_acc: 0.8947
# Epoch 61/128
# 4s - loss: 0.4829 - acc: 0.8246 - top3_acc: 0.9825 - val_loss: 0.9705 - val_acc: 0.7105 - val_top3_acc: 0.8947
# Epoch 62/128
# 4s - loss: 0.6523 - acc: 0.8158 - top3_acc: 0.9649 - val_loss: 1.0568 - val_acc: 0.6053 - val_top3_acc: 0.8947
# Epoch 63/128
# 4s - loss: 0.7420 - acc: 0.7632 - top3_acc: 0.9649 - val_loss: 0.9653 - val_acc: 0.6842 - val_top3_acc: 0.8947
# Epoch 64/128
# 4s - loss: 0.7162 - acc: 0.7982 - top3_acc: 0.9561 - val_loss: 1.0803 - val_acc: 0.6316 - val_top3_acc: 0.8421
# Epoch 65/128
# 4s - loss: 0.6864 - acc: 0.7895 - top3_acc: 0.9649 - val_loss: 1.1474 - val_acc: 0.6053 - val_top3_acc: 0.8421
# Epoch 66/128
# 4s - loss: 0.7080 - acc: 0.7895 - top3_acc: 0.9737 - val_loss: 1.1419 - val_acc: 0.6579 - val_top3_acc: 0.8421
# Epoch 67/128
# 4s - loss: 0.5966 - acc: 0.7719 - top3_acc: 0.9825 - val_loss: 1.1226 - val_acc: 0.6316 - val_top3_acc: 0.8421
# Epoch 68/128
# 4s - loss: 0.5519 - acc: 0.8070 - top3_acc: 0.9649 - val_loss: 1.0496 - val_acc: 0.6579 - val_top3_acc: 0.8684
# Epoch 69/128
# 4s - loss: 0.5464 - acc: 0.7807 - top3_acc: 0.9825 - val_loss: 1.1763 - val_acc: 0.6053 - val_top3_acc: 0.8421
# Epoch 70/128
# 4s - loss: 0.6655 - acc: 0.7807 - top3_acc: 0.9825 - val_loss: 1.1786 - val_acc: 0.6842 - val_top3_acc: 0.8421
# Epoch 71/128
# 4s - loss: 0.5923 - acc: 0.8421 - top3_acc: 0.9825 - val_loss: 1.1199 - val_acc: 0.6316 - val_top3_acc: 0.8947
# Epoch 72/128
# 4s - loss: 0.6741 - acc: 0.8158 - top3_acc: 0.9561 - val_loss: 1.2106 - val_acc: 0.6579 - val_top3_acc: 0.8421
# Epoch 73/128
# 4s - loss: 0.4892 - acc: 0.7632 - top3_acc: 0.9912 - val_loss: 1.1543 - val_acc: 0.6842 - val_top3_acc: 0.8684
# Epoch 74/128
# 4s - loss: 0.5341 - acc: 0.8509 - top3_acc: 0.9825 - val_loss: 1.1679 - val_acc: 0.6842 - val_top3_acc: 0.8684
# Epoch 75/128
# 4s - loss: 0.4326 - acc: 0.8596 - top3_acc: 0.9825 - val_loss: 1.2484 - val_acc: 0.6842 - val_top3_acc: 0.8684
# Epoch 76/128
# 4s - loss: 0.3792 - acc: 0.8421 - top3_acc: 0.9912 - val_loss: 1.2811 - val_acc: 0.6579 - val_top3_acc: 0.8421
# Epoch 77/128
# 4s - loss: 0.3993 - acc: 0.8509 - top3_acc: 1.0000 - val_loss: 1.2289 - val_acc: 0.6053 - val_top3_acc: 0.8684
# Epoch 78/128
# 4s - loss: 0.7194 - acc: 0.8509 - top3_acc: 0.9737 - val_loss: 1.0490 - val_acc: 0.7105 - val_top3_acc: 0.8684
# Epoch 79/128
# 4s - loss: 0.5094 - acc: 0.8421 - top3_acc: 0.9649 - val_loss: 1.0609 - val_acc: 0.6316 - val_top3_acc: 0.9211
# Epoch 80/128
# 4s - loss: 0.2733 - acc: 0.9035 - top3_acc: 1.0000 - val_loss: 1.0755 - val_acc: 0.6316 - val_top3_acc: 0.8947
# Epoch 81/128
# 4s - loss: 0.3637 - acc: 0.8596 - top3_acc: 1.0000 - val_loss: 1.0730 - val_acc: 0.6579 - val_top3_acc: 0.8684
# Epoch 82/128
# 4s - loss: 0.5015 - acc: 0.8772 - top3_acc: 0.9912 - val_loss: 1.0679 - val_acc: 0.6579 - val_top3_acc: 0.9211
# Epoch 83/128
# 4s - loss: 0.3810 - acc: 0.8684 - top3_acc: 1.0000 - val_loss: 0.9958 - val_acc: 0.6842 - val_top3_acc: 0.8947
# Epoch 84/128
# 4s - loss: 0.4119 - acc: 0.8684 - top3_acc: 0.9825 - val_loss: 1.0578 - val_acc: 0.6842 - val_top3_acc: 0.8684
# Epoch 85/128
# 4s - loss: 0.3628 - acc: 0.8947 - top3_acc: 0.9737 - val_loss: 0.9994 - val_acc: 0.7105 - val_top3_acc: 0.9211
# Epoch 86/128
# 4s - loss: 0.2871 - acc: 0.8947 - top3_acc: 1.0000 - val_loss: 1.0029 - val_acc: 0.7368 - val_top3_acc: 0.8947
# Epoch 87/128
# 4s - loss: 0.3587 - acc: 0.8421 - top3_acc: 0.9912 - val_loss: 1.0250 - val_acc: 0.7368 - val_top3_acc: 0.8947
# Epoch 88/128
# 4s - loss: 0.3335 - acc: 0.8947 - top3_acc: 1.0000 - val_loss: 0.9252 - val_acc: 0.7368 - val_top3_acc: 0.9211
# Epoch 89/128
# 4s - loss: 0.4368 - acc: 0.9123 - top3_acc: 0.9825 - val_loss: 1.1299 - val_acc: 0.7105 - val_top3_acc: 0.8947
# Epoch 90/128
# 4s - loss: 0.2431 - acc: 0.9123 - top3_acc: 0.9912 - val_loss: 1.1717 - val_acc: 0.7368 - val_top3_acc: 0.8947
# Epoch 91/128
# 4s - loss: 0.2254 - acc: 0.9123 - top3_acc: 1.0000 - val_loss: 0.9508 - val_acc: 0.7895 - val_top3_acc: 0.9211
# Epoch 92/128
# 4s - loss: 0.3564 - acc: 0.8509 - top3_acc: 0.9825 - val_loss: 1.2293 - val_acc: 0.7368 - val_top3_acc: 0.8421
# Epoch 93/128
# 4s - loss: 0.6552 - acc: 0.7719 - top3_acc: 1.0000 - val_loss: 1.0969 - val_acc: 0.7368 - val_top3_acc: 0.8947
# Epoch 94/128
# 4s - loss: 0.3923 - acc: 0.8596 - top3_acc: 0.9912 - val_loss: 0.8039 - val_acc: 0.7368 - val_top3_acc: 0.8947
# Epoch 95/128
# 4s - loss: 0.4204 - acc: 0.8947 - top3_acc: 0.9825 - val_loss: 1.0700 - val_acc: 0.6842 - val_top3_acc: 0.8421
# Epoch 96/128
# 4s - loss: 0.3261 - acc: 0.8860 - top3_acc: 0.9825 - val_loss: 0.9224 - val_acc: 0.7632 - val_top3_acc: 0.9211
# Epoch 97/128
# 4s - loss: 0.2050 - acc: 0.8860 - top3_acc: 1.0000 - val_loss: 0.8528 - val_acc: 0.7632 - val_top3_acc: 0.8947
# Epoch 98/128
# 4s - loss: 0.3141 - acc: 0.9035 - top3_acc: 1.0000 - val_loss: 1.1226 - val_acc: 0.7632 - val_top3_acc: 0.9211
# Epoch 99/128
# 4s - loss: 0.3446 - acc: 0.8596 - top3_acc: 1.0000 - val_loss: 1.0492 - val_acc: 0.7632 - val_top3_acc: 0.8684
# Epoch 100/128
# 4s - loss: 0.3126 - acc: 0.8772 - top3_acc: 1.0000 - val_loss: 0.8604 - val_acc: 0.7368 - val_top3_acc: 0.8947
# Epoch 101/128
# 4s - loss: 0.2724 - acc: 0.9298 - top3_acc: 1.0000 - val_loss: 0.8523 - val_acc: 0.6579 - val_top3_acc: 0.8947
# Epoch 102/128
# 4s - loss: 0.3862 - acc: 0.8684 - top3_acc: 0.9912 - val_loss: 1.0519 - val_acc: 0.6579 - val_top3_acc: 0.8684
# Epoch 103/128
# 4s - loss: 0.2315 - acc: 0.8684 - top3_acc: 1.0000 - val_loss: 0.8881 - val_acc: 0.6842 - val_top3_acc: 0.9211
# Epoch 104/128
# 4s - loss: 0.3259 - acc: 0.8684 - top3_acc: 0.9912 - val_loss: 0.7690 - val_acc: 0.6316 - val_top3_acc: 0.9474
# Epoch 105/128
# 4s - loss: 0.2471 - acc: 0.8860 - top3_acc: 1.0000 - val_loss: 0.7499 - val_acc: 0.7895 - val_top3_acc: 0.8947
# Epoch 106/128
# 4s - loss: 0.2354 - acc: 0.9035 - top3_acc: 1.0000 - val_loss: 0.7649 - val_acc: 0.7368 - val_top3_acc: 0.9211
# Epoch 107/128
# 4s - loss: 0.2482 - acc: 0.9298 - top3_acc: 0.9912 - val_loss: 0.8726 - val_acc: 0.7105 - val_top3_acc: 0.9211
# Epoch 108/128
# 4s - loss: 0.2767 - acc: 0.8684 - top3_acc: 1.0000 - val_loss: 0.8585 - val_acc: 0.7895 - val_top3_acc: 0.8947
# Epoch 109/128
# 4s - loss: 0.1668 - acc: 0.9561 - top3_acc: 1.0000 - val_loss: 1.1692 - val_acc: 0.6579 - val_top3_acc: 0.8421
# Epoch 110/128
# 4s - loss: 0.4038 - acc: 0.8684 - top3_acc: 0.9825 - val_loss: 0.7726 - val_acc: 0.7632 - val_top3_acc: 0.9211
# Epoch 111/128
# 4s - loss: 0.2248 - acc: 0.9386 - top3_acc: 1.0000 - val_loss: 0.7920 - val_acc: 0.7105 - val_top3_acc: 0.8684
# Epoch 112/128
# 4s - loss: 0.1834 - acc: 0.9123 - top3_acc: 1.0000 - val_loss: 0.8567 - val_acc: 0.7105 - val_top3_acc: 0.8947
# Epoch 113/128
# 4s - loss: 0.1833 - acc: 0.9561 - top3_acc: 1.0000 - val_loss: 0.7406 - val_acc: 0.7368 - val_top3_acc: 0.8947
# Epoch 114/128
# 4s - loss: 0.2489 - acc: 0.9035 - top3_acc: 0.9912 - val_loss: 0.8185 - val_acc: 0.7105 - val_top3_acc: 0.8684
# Epoch 115/128
# 4s - loss: 0.2157 - acc: 0.9211 - top3_acc: 0.9825 - val_loss: 0.6990 - val_acc: 0.7368 - val_top3_acc: 0.9211
# Epoch 116/128
# 4s - loss: 0.1693 - acc: 0.9386 - top3_acc: 1.0000 - val_loss: 0.7717 - val_acc: 0.7368 - val_top3_acc: 0.9211
# Epoch 117/128
# 4s - loss: 0.1781 - acc: 0.9474 - top3_acc: 1.0000 - val_loss: 0.7277 - val_acc: 0.7632 - val_top3_acc: 0.9211
# Epoch 118/128
# 4s - loss: 0.1761 - acc: 0.9298 - top3_acc: 1.0000 - val_loss: 1.0997 - val_acc: 0.6842 - val_top3_acc: 0.8947
# Epoch 119/128
# 4s - loss: 0.4785 - acc: 0.8596 - top3_acc: 1.0000 - val_loss: 1.4888 - val_acc: 0.6053 - val_top3_acc: 0.8684
# Epoch 120/128
# 4s - loss: 0.1622 - acc: 0.9474 - top3_acc: 1.0000 - val_loss: 1.3502 - val_acc: 0.6842 - val_top3_acc: 0.8947
# Epoch 121/128
# 4s - loss: 0.1572 - acc: 0.9474 - top3_acc: 0.9912 - val_loss: 1.3605 - val_acc: 0.6316 - val_top3_acc: 0.8947
# Epoch 122/128
# 4s - loss: 0.2369 - acc: 0.9474 - top3_acc: 0.9912 - val_loss: 1.3228 - val_acc: 0.6842 - val_top3_acc: 0.9211
# Epoch 123/128
# 4s - loss: 0.1608 - acc: 0.9386 - top3_acc: 1.0000 - val_loss: 1.3302 - val_acc: 0.6842 - val_top3_acc: 0.8947
# Epoch 124/128
# 4s - loss: 0.1560 - acc: 0.9649 - top3_acc: 1.0000 - val_loss: 1.1365 - val_acc: 0.6842 - val_top3_acc: 0.9211
# Epoch 125/128
# 4s - loss: 0.2410 - acc: 0.9386 - top3_acc: 1.0000 - val_loss: 1.3508 - val_acc: 0.7105 - val_top3_acc: 0.9211
# Epoch 126/128
# 4s - loss: 0.1390 - acc: 0.9649 - top3_acc: 1.0000 - val_loss: 1.3436 - val_acc: 0.6579 - val_top3_acc: 0.8684
# Epoch 127/128
# 4s - loss: 0.2275 - acc: 0.9035 - top3_acc: 1.0000 - val_loss: 1.4946 - val_acc: 0.6579 - val_top3_acc: 0.8947
# Epoch 128/128
# 4s - loss: 0.2943 - acc: 0.9035 - top3_acc: 1.0000 - val_loss: 1.4959 - val_acc: 0.6579 - val_top3_acc: 0.9211

# %%
scores = model_test.evaluate(htrain_x, htrain_y, verbose=1)
print('Training Loss:', scores[0])
print('Training Accuracy:', scores[1]*100,'%')
print('Training Top 3 Accuracy:', scores[2]*100,'%')
scores = model_test.evaluate(htest_x, htest_y, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1]*100,'%')
print('Training Top 3 Accuracy:', scores[2]*100,'%')
# Out:
# 114/114 [==============================] - 1s
# Training Loss: 0.139823080776
# Training Accuracy: 96.4912280702 %
# Training Top 3 Accuracy: 100.0 %
# 38/38 [==============================] - 0s
# Test loss: 1.49589552377
# Test accuracy: 65.7894736842 %
# Training Top 3 Accuracy: 92.1052631579 %

# %% [markdown]
# #### Adam
# The adam optimizer returned the best results with the validation set top 3 acccuracy peaking at 97% (refer graph).
# <br><br>Training Loss: 0.0058015209639
# <br>Training Accuracy: 100.0 %
# <br>Training Top 3 Accuracy: 100.0 %
# <br>Test loss: 0.764951594566
# <br>Test accuracy: 84.2105263158 %
# <br>Training Top 3 Accuracy: 94.7368421053 % (peaked @ 97.3%)
# <br>Approximate training time: 15 minutes

# %%
model = Sequential()
model.add(GRU(128, input_shape=(htrain_x.shape[1], htrain_x.shape[2]),return_sequences=True))
model.add(Dropout(0.4))
model.add(GRU(64, input_shape=(htrain_x.shape[1], htrain_x.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(19))
model.add(Activation('softmax'))
model.compile(loss='sparse_categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy', top3_acc])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_7 (GRU)                  (None, 300, 128)          78336
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 300, 128)          0
# _________________________________________________________________
# gru_8 (GRU)                  (None, 64)                37056
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 19)                1235
# _________________________________________________________________
# activation_8 (Activation)    (None, 19)                0
# =================================================================
# Total params: 116,627
# Trainable params: 116,627
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Save/Load the model weights
save = False
if(save):
    model.save_weights("hf_deep_gru_weights.h5")
    print('Saved trained model and weights')
else:
    model.load_weights("hf_deep_gru_weights.h5")

# %%
history = model.fit(htrain_x, htrain_y, epochs=128, batch_size=64, validation_data=(htest_x, htest_y), verbose=2, shuffle=True)
# Out:
# Train on 114 samples, validate on 38 samples
# Epoch 1/128
# 6s - loss: 3.1647 - acc: 0.0526 - top3_acc: 0.1228 - val_loss: 3.0217 - val_acc: 0.0526 - val_top3_acc: 0.1579
# Epoch 2/128
# 4s - loss: 2.8676 - acc: 0.1404 - top3_acc: 0.2632 - val_loss: 2.8070 - val_acc: 0.1842 - val_top3_acc: 0.3421
# Epoch 3/128
# 4s - loss: 2.6692 - acc: 0.1842 - top3_acc: 0.3860 - val_loss: 2.6512 - val_acc: 0.2632 - val_top3_acc: 0.3684
# Epoch 4/128
# 4s - loss: 2.5202 - acc: 0.2193 - top3_acc: 0.5263 - val_loss: 2.5188 - val_acc: 0.2632 - val_top3_acc: 0.4474
# Epoch 5/128
# 4s - loss: 2.3664 - acc: 0.3158 - top3_acc: 0.6053 - val_loss: 2.4090 - val_acc: 0.3158 - val_top3_acc: 0.5000
# Epoch 6/128
# 4s - loss: 2.2503 - acc: 0.3772 - top3_acc: 0.6667 - val_loss: 2.3063 - val_acc: 0.3684 - val_top3_acc: 0.6053
# Epoch 7/128
# 4s - loss: 2.1400 - acc: 0.4298 - top3_acc: 0.7018 - val_loss: 2.2161 - val_acc: 0.3684 - val_top3_acc: 0.6842
# Epoch 8/128
# 4s - loss: 1.9916 - acc: 0.6053 - top3_acc: 0.7895 - val_loss: 2.1315 - val_acc: 0.3947 - val_top3_acc: 0.7368
# Epoch 9/128
# 4s - loss: 1.8934 - acc: 0.5965 - top3_acc: 0.8158 - val_loss: 2.0533 - val_acc: 0.4474 - val_top3_acc: 0.7895
# Epoch 10/128
# 4s - loss: 1.8104 - acc: 0.5965 - top3_acc: 0.8684 - val_loss: 1.9761 - val_acc: 0.4474 - val_top3_acc: 0.7895
# Epoch 11/128
# 4s - loss: 1.7037 - acc: 0.6404 - top3_acc: 0.8333 - val_loss: 1.9096 - val_acc: 0.4737 - val_top3_acc: 0.8158
# Epoch 12/128
# 4s - loss: 1.6482 - acc: 0.6842 - top3_acc: 0.8860 - val_loss: 1.8475 - val_acc: 0.4737 - val_top3_acc: 0.8158
# Epoch 13/128
# 4s - loss: 1.5542 - acc: 0.7018 - top3_acc: 0.9035 - val_loss: 1.7851 - val_acc: 0.5263 - val_top3_acc: 0.8158
# Epoch 14/128
# 4s - loss: 1.4930 - acc: 0.7018 - top3_acc: 0.9035 - val_loss: 1.7248 - val_acc: 0.5789 - val_top3_acc: 0.8158
# Epoch 15/128
# 4s - loss: 1.4009 - acc: 0.7193 - top3_acc: 0.9474 - val_loss: 1.6707 - val_acc: 0.5526 - val_top3_acc: 0.8421
# Epoch 16/128
# 4s - loss: 1.3242 - acc: 0.7456 - top3_acc: 0.9474 - val_loss: 1.6189 - val_acc: 0.5526 - val_top3_acc: 0.7895
# Epoch 17/128
# 4s - loss: 1.2725 - acc: 0.7719 - top3_acc: 0.9649 - val_loss: 1.5706 - val_acc: 0.5526 - val_top3_acc: 0.7895
# Epoch 18/128
# 4s - loss: 1.2042 - acc: 0.7895 - top3_acc: 0.9474 - val_loss: 1.5240 - val_acc: 0.5526 - val_top3_acc: 0.7895
# Epoch 19/128
# 4s - loss: 1.1362 - acc: 0.7544 - top3_acc: 0.9474 - val_loss: 1.4763 - val_acc: 0.6053 - val_top3_acc: 0.8421
# Epoch 20/128
# 4s - loss: 1.0961 - acc: 0.8070 - top3_acc: 0.9649 - val_loss: 1.4359 - val_acc: 0.6316 - val_top3_acc: 0.8421
# Epoch 21/128
# 4s - loss: 1.0116 - acc: 0.8333 - top3_acc: 0.9737 - val_loss: 1.3954 - val_acc: 0.6053 - val_top3_acc: 0.8421
# Epoch 22/128
# 4s - loss: 0.9402 - acc: 0.8772 - top3_acc: 0.9825 - val_loss: 1.3572 - val_acc: 0.6316 - val_top3_acc: 0.8421
# Epoch 23/128
# 4s - loss: 0.8915 - acc: 0.7982 - top3_acc: 0.9912 - val_loss: 1.3247 - val_acc: 0.6316 - val_top3_acc: 0.8421
# Epoch 24/128
# 4s - loss: 0.8367 - acc: 0.8246 - top3_acc: 0.9912 - val_loss: 1.2915 - val_acc: 0.6579 - val_top3_acc: 0.8421
# Epoch 25/128
# 4s - loss: 0.7908 - acc: 0.8421 - top3_acc: 0.9912 - val_loss: 1.2530 - val_acc: 0.6842 - val_top3_acc: 0.8947
# Epoch 26/128
# 4s - loss: 0.7149 - acc: 0.9298 - top3_acc: 1.0000 - val_loss: 1.2198 - val_acc: 0.6842 - val_top3_acc: 0.8947
# Epoch 27/128
# 4s - loss: 0.7018 - acc: 0.8509 - top3_acc: 1.0000 - val_loss: 1.1882 - val_acc: 0.6842 - val_top3_acc: 0.8947
# Epoch 28/128
# 4s - loss: 0.6113 - acc: 0.9298 - top3_acc: 1.0000 - val_loss: 1.1589 - val_acc: 0.7105 - val_top3_acc: 0.8947
# Epoch 29/128
# 4s - loss: 0.6030 - acc: 0.9298 - top3_acc: 1.0000 - val_loss: 1.1422 - val_acc: 0.7368 - val_top3_acc: 0.8947
# Epoch 30/128
# 4s - loss: 0.5604 - acc: 0.9035 - top3_acc: 1.0000 - val_loss: 1.1215 - val_acc: 0.7632 - val_top3_acc: 0.8947
# Epoch 31/128
# 4s - loss: 0.5435 - acc: 0.9211 - top3_acc: 1.0000 - val_loss: 1.1000 - val_acc: 0.7368 - val_top3_acc: 0.8947
# Epoch 32/128
# 4s - loss: 0.4676 - acc: 0.9386 - top3_acc: 1.0000 - val_loss: 1.0701 - val_acc: 0.7368 - val_top3_acc: 0.8947
# Epoch 33/128
# 4s - loss: 0.4869 - acc: 0.9298 - top3_acc: 1.0000 - val_loss: 1.0464 - val_acc: 0.7105 - val_top3_acc: 0.8947
# Epoch 34/128
# 4s - loss: 0.4514 - acc: 0.9649 - top3_acc: 1.0000 - val_loss: 1.0223 - val_acc: 0.7105 - val_top3_acc: 0.8947
# Epoch 35/128
# 4s - loss: 0.4419 - acc: 0.9386 - top3_acc: 1.0000 - val_loss: 1.0038 - val_acc: 0.6842 - val_top3_acc: 0.8947
# Epoch 36/128
# 4s - loss: 0.3867 - acc: 0.9649 - top3_acc: 1.0000 - val_loss: 0.9753 - val_acc: 0.6316 - val_top3_acc: 0.9211
# Epoch 37/128
# 4s - loss: 0.3605 - acc: 0.9386 - top3_acc: 1.0000 - val_loss: 0.9356 - val_acc: 0.7105 - val_top3_acc: 0.9474
# Epoch 38/128
# 4s - loss: 0.3589 - acc: 0.9737 - top3_acc: 1.0000 - val_loss: 0.9035 - val_acc: 0.7105 - val_top3_acc: 0.8947
# Epoch 39/128
# 4s - loss: 0.3294 - acc: 0.9737 - top3_acc: 1.0000 - val_loss: 0.8895 - val_acc: 0.7105 - val_top3_acc: 0.8947
# Epoch 40/128
# 8s - loss: 0.3034 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 0.8841 - val_acc: 0.7105 - val_top3_acc: 0.9211
# Epoch 41/128
# 7s - loss: 0.2823 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.8841 - val_acc: 0.7632 - val_top3_acc: 0.9211
# Epoch 42/128
# 7s - loss: 0.2768 - acc: 0.9649 - top3_acc: 1.0000 - val_loss: 0.8851 - val_acc: 0.7368 - val_top3_acc: 0.9211
# Epoch 43/128
# 7s - loss: 0.2850 - acc: 0.9649 - top3_acc: 1.0000 - val_loss: 0.8927 - val_acc: 0.7368 - val_top3_acc: 0.8947
# Epoch 44/128
# 7s - loss: 0.2368 - acc: 0.9649 - top3_acc: 1.0000 - val_loss: 0.8680 - val_acc: 0.7368 - val_top3_acc: 0.9211
# Epoch 45/128
# 7s - loss: 0.2242 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 0.8435 - val_acc: 0.7368 - val_top3_acc: 0.9474
# Epoch 46/128
# 7s - loss: 0.2200 - acc: 0.9649 - top3_acc: 1.0000 - val_loss: 0.8171 - val_acc: 0.7895 - val_top3_acc: 0.9474
# Epoch 47/128
# 7s - loss: 0.1890 - acc: 0.9649 - top3_acc: 1.0000 - val_loss: 0.8133 - val_acc: 0.7632 - val_top3_acc: 0.9474
# Epoch 48/128
# 7s - loss: 0.1882 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.8216 - val_acc: 0.7632 - val_top3_acc: 0.9211
# Epoch 49/128
# 7s - loss: 0.1952 - acc: 0.9737 - top3_acc: 1.0000 - val_loss: 0.8295 - val_acc: 0.7632 - val_top3_acc: 0.9474
# Epoch 50/128
# 7s - loss: 0.1661 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.8145 - val_acc: 0.7895 - val_top3_acc: 0.9474
# Epoch 51/128
# 7s - loss: 0.1484 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.7870 - val_acc: 0.7632 - val_top3_acc: 0.9474
# Epoch 52/128
# 8s - loss: 0.1545 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.7811 - val_acc: 0.7632 - val_top3_acc: 0.9211
# Epoch 53/128
# 5s - loss: 0.1444 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.7856 - val_acc: 0.7632 - val_top3_acc: 0.9211
# Epoch 54/128
# 4s - loss: 0.1453 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 0.7899 - val_acc: 0.7632 - val_top3_acc: 0.8947
# Epoch 55/128
# 4s - loss: 0.1446 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 0.7934 - val_acc: 0.7632 - val_top3_acc: 0.8947
# Epoch 56/128
# 4s - loss: 0.1366 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 0.7726 - val_acc: 0.7632 - val_top3_acc: 0.9211
# Epoch 57/128
# 5s - loss: 0.1151 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 0.7435 - val_acc: 0.7632 - val_top3_acc: 0.9211
# Epoch 58/128
# 7s - loss: 0.1020 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.7224 - val_acc: 0.7895 - val_top3_acc: 0.9474
# Epoch 59/128
# 7s - loss: 0.0910 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7092 - val_acc: 0.8158 - val_top3_acc: 0.9474
# Epoch 60/128
# 7s - loss: 0.0948 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7000 - val_acc: 0.8158 - val_top3_acc: 0.9211
# Epoch 61/128
# 7s - loss: 0.0903 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.6957 - val_acc: 0.8158 - val_top3_acc: 0.9211
# Epoch 62/128
# 7s - loss: 0.0993 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.6944 - val_acc: 0.8158 - val_top3_acc: 0.9211
# Epoch 63/128
# 7s - loss: 0.0887 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.7082 - val_acc: 0.8158 - val_top3_acc: 0.9211
# Epoch 64/128
# 7s - loss: 0.0924 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 0.7045 - val_acc: 0.8158 - val_top3_acc: 0.9211
# Epoch 65/128
# 8s - loss: 0.0835 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.8118 - val_acc: 0.7632 - val_top3_acc: 0.9474
# Epoch 66/128
# 7s - loss: 0.0940 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.7921 - val_acc: 0.8158 - val_top3_acc: 0.9474
# Epoch 67/128
# 4s - loss: 0.0786 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.7936 - val_acc: 0.7632 - val_top3_acc: 0.9211
# Epoch 68/128
# 4s - loss: 0.0816 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.6992 - val_acc: 0.8158 - val_top3_acc: 0.9211
# Epoch 69/128
# 4s - loss: 0.0904 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 0.6604 - val_acc: 0.8684 - val_top3_acc: 0.9211
# Epoch 70/128
# 4s - loss: 0.1142 - acc: 0.9737 - top3_acc: 1.0000 - val_loss: 0.6833 - val_acc: 0.8158 - val_top3_acc: 0.9211
# Epoch 71/128
# 6s - loss: 0.1050 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.7673 - val_acc: 0.8158 - val_top3_acc: 0.9211
# Epoch 72/128
# 7s - loss: 0.1186 - acc: 0.9737 - top3_acc: 1.0000 - val_loss: 0.8163 - val_acc: 0.7632 - val_top3_acc: 0.9211
# Epoch 73/128
# 7s - loss: 0.0987 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.8270 - val_acc: 0.7895 - val_top3_acc: 0.9211
# Epoch 74/128
# 8s - loss: 0.0883 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.8145 - val_acc: 0.7895 - val_top3_acc: 0.9211
# Epoch 75/128
# 9s - loss: 0.1058 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.7984 - val_acc: 0.8421 - val_top3_acc: 0.9211
# Epoch 76/128
# 9s - loss: 0.0700 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7869 - val_acc: 0.8421 - val_top3_acc: 0.9211
# Epoch 77/128
# 8s - loss: 0.0776 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.7844 - val_acc: 0.8421 - val_top3_acc: 0.9211
# Epoch 78/128
# 8s - loss: 0.0690 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7727 - val_acc: 0.8421 - val_top3_acc: 0.9211
# Epoch 79/128
# 8s - loss: 0.0884 - acc: 0.9737 - top3_acc: 1.0000 - val_loss: 0.7705 - val_acc: 0.8421 - val_top3_acc: 0.9211
# Epoch 80/128
# 8s - loss: 0.0681 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.7907 - val_acc: 0.8158 - val_top3_acc: 0.9211
# Epoch 81/128
# 8s - loss: 0.0651 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.8101 - val_acc: 0.8158 - val_top3_acc: 0.9211
# Epoch 82/128
# 8s - loss: 0.0747 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 0.8055 - val_acc: 0.8158 - val_top3_acc: 0.9211
# Epoch 83/128
# 9s - loss: 0.0807 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 0.8638 - val_acc: 0.7368 - val_top3_acc: 0.9474
# Epoch 84/128
# 6s - loss: 0.0920 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 0.7829 - val_acc: 0.8158 - val_top3_acc: 0.9211
# Epoch 85/128
# 4s - loss: 0.0508 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7478 - val_acc: 0.8421 - val_top3_acc: 0.9474
# Epoch 86/128
# 4s - loss: 0.0654 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 0.7339 - val_acc: 0.8421 - val_top3_acc: 0.9737
# Epoch 87/128
# 4s - loss: 0.0601 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.6967 - val_acc: 0.8421 - val_top3_acc: 0.9474
# Epoch 88/128
# 5s - loss: 0.0477 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7100 - val_acc: 0.8158 - val_top3_acc: 0.9474
# Epoch 89/128
# 8s - loss: 0.0575 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.7193 - val_acc: 0.8421 - val_top3_acc: 0.9474
# Epoch 90/128
# 8s - loss: 0.0464 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.7263 - val_acc: 0.8421 - val_top3_acc: 0.9474
# Epoch 91/128
# 8s - loss: 0.0494 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.7409 - val_acc: 0.8158 - val_top3_acc: 0.9211
# Epoch 92/128
# 9s - loss: 0.0379 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7681 - val_acc: 0.8158 - val_top3_acc: 0.9211
# Epoch 93/128
# 5s - loss: 0.0426 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7830 - val_acc: 0.7895 - val_top3_acc: 0.9211
# Epoch 94/128
# 4s - loss: 0.0365 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7648 - val_acc: 0.8158 - val_top3_acc: 0.9211
# Epoch 95/128
# 7s - loss: 0.0418 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.7490 - val_acc: 0.8158 - val_top3_acc: 0.9211
# Epoch 96/128
# 8s - loss: 0.0375 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.7421 - val_acc: 0.8158 - val_top3_acc: 0.9211
# Epoch 97/128
# 8s - loss: 0.0385 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.7376 - val_acc: 0.8158 - val_top3_acc: 0.9211
# Epoch 98/128
# 9s - loss: 0.0355 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7322 - val_acc: 0.8158 - val_top3_acc: 0.9474
# Epoch 99/128
# 8s - loss: 0.0315 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7203 - val_acc: 0.8421 - val_top3_acc: 0.9474
# Epoch 100/128
# 8s - loss: 0.0409 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.6999 - val_acc: 0.8421 - val_top3_acc: 0.9211
# Epoch 101/128
# 4s - loss: 0.0323 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7045 - val_acc: 0.8421 - val_top3_acc: 0.9211
# Epoch 102/128
# 4s - loss: 0.0311 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7122 - val_acc: 0.8421 - val_top3_acc: 0.9211
# Epoch 103/128
# 4s - loss: 0.0328 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 0.6996 - val_acc: 0.8421 - val_top3_acc: 0.9474
# Epoch 104/128
# 4s - loss: 0.0245 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7004 - val_acc: 0.8421 - val_top3_acc: 0.9474
# Epoch 105/128
# 5s - loss: 0.0243 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7150 - val_acc: 0.8421 - val_top3_acc: 0.9737
# Epoch 106/128
# 8s - loss: 0.0260 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7273 - val_acc: 0.8421 - val_top3_acc: 0.9737
# Epoch 107/128
# 8s - loss: 0.0261 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7227 - val_acc: 0.8421 - val_top3_acc: 0.9737
# Epoch 108/128
# 8s - loss: 0.0225 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7198 - val_acc: 0.8421 - val_top3_acc: 0.9737
# Epoch 109/128
# 9s - loss: 0.0211 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7210 - val_acc: 0.8421 - val_top3_acc: 0.9474
# Epoch 110/128
# 10s - loss: 0.0230 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7259 - val_acc: 0.8421 - val_top3_acc: 0.9474
# Epoch 111/128
# 9s - loss: 0.0193 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7312 - val_acc: 0.8421 - val_top3_acc: 0.9474
# Epoch 112/128
# 8s - loss: 0.0222 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7275 - val_acc: 0.8421 - val_top3_acc: 0.9474
# Epoch 113/128
# 6s - loss: 0.0192 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7296 - val_acc: 0.8421 - val_top3_acc: 0.9474
# Epoch 114/128
# 4s - loss: 0.0192 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7343 - val_acc: 0.8421 - val_top3_acc: 0.9737
# Epoch 115/128
# 4s - loss: 0.0187 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7409 - val_acc: 0.8421 - val_top3_acc: 0.9737
# Epoch 116/128
# 4s - loss: 0.0176 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7481 - val_acc: 0.8421 - val_top3_acc: 0.9737
# Epoch 117/128
# 4s - loss: 0.0165 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7531 - val_acc: 0.8421 - val_top3_acc: 0.9737
# Epoch 118/128
# 8s - loss: 0.0187 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7557 - val_acc: 0.8421 - val_top3_acc: 0.9737
# Epoch 119/128
# 8s - loss: 0.0184 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7578 - val_acc: 0.8421 - val_top3_acc: 0.9737
# Epoch 120/128
# 8s - loss: 0.0187 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7594 - val_acc: 0.8421 - val_top3_acc: 0.9737
# Epoch 121/128
# 8s - loss: 0.0193 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7614 - val_acc: 0.8421 - val_top3_acc: 0.9474
# Epoch 122/128
# 8s - loss: 0.0168 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7629 - val_acc: 0.8421 - val_top3_acc: 0.9474
# Epoch 123/128
# 7s - loss: 0.0170 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7641 - val_acc: 0.8421 - val_top3_acc: 0.9474
# Epoch 124/128
# 4s - loss: 0.0149 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7660 - val_acc: 0.8421 - val_top3_acc: 0.9474
# Epoch 125/128
# 4s - loss: 0.0145 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7663 - val_acc: 0.8421 - val_top3_acc: 0.9474
# Epoch 126/128
# 4s - loss: 0.0171 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7647 - val_acc: 0.8421 - val_top3_acc: 0.9474
# Epoch 127/128
# 4s - loss: 0.0144 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7641 - val_acc: 0.8421 - val_top3_acc: 0.9737
# Epoch 128/128
# 8s - loss: 0.0162 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 0.7650 - val_acc: 0.8421 - val_top3_acc: 0.9474

# %% [markdown]
# ### Training Metrics Visualization
# here we can observe the loss, accuracy and top3 accuracy metrics for our training and test datasets along the training cycle.

# %%
# plot history
plt.figure(figsize=[20,4])
plt.subplot(131)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Test')
plt.title("Loss metrics")
plt.legend()
plt.subplot(132)
plt.plot(history.history['acc'], label='Train Acc')
plt.plot(history.history['val_acc'], label='Test Acc')
plt.title("Accuracy metrics")
plt.legend()
plt.subplot(133)
plt.plot(history.history['top3_acc'][:150], label='Train TopK')
plt.plot(history.history['val_top3_acc'][:150], label='Test TopK')
plt.title("Top 3 Accuracy")
plt.legend()
plt.show()

# %%
scores = model.evaluate(htrain_x, htrain_y, verbose=1)
print('Training Loss:', scores[0])
print('Training Accuracy:', scores[1]*100,'%')
print('Training Top 3 Accuracy:', scores[2]*100,'%')
scores = model.evaluate(htest_x, htest_y, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1]*100,'%')
print('Training Top 3 Accuracy:', scores[2]*100,'%')
# Out:
# 114/114 [==============================] - 1s
# Training Loss: 0.0058015209639
# Training Accuracy: 100.0 %
# Training Top 3 Accuracy: 100.0 %
# 38/38 [==============================] - 0s
# Test loss: 0.764951594566
# Test accuracy: 84.2105263158 %
# Training Top 3 Accuracy: 94.7368421053 %

# %% [markdown]
# #### confusion matrix for the final model

# %%
plt.figure(figsize=[15,5])
plt.subplot(121)
sn.heatmap(metrics.confusion_matrix(htrain_y, model.predict_classes(htrain_x)))

plt.subplot(122)
sn.heatmap(metrics.confusion_matrix(htest_y, model.predict_classes(htest_x)))
# Out:
# 114/114 [==============================] - 1s
# 38/38 [==============================] - 0s

# %% [markdown]
# ### 1-Dimensional Convolutional Neural Network
# Another interesting model for pattern detection is the convolution neural network, while usually used for image classification, convolutional neural networks are proven to work well with sequence data.<br>
# we achieved the following metrics from the model:
# <br><br>Training Loss: 0.00405181182029
# <br>Training Accuracy: 100.0 %
# <br>Training Top 3 Accuracy: 100.0 %
# <br>Test loss: 1.59485659474
# <br>Test accuracy: 73.6842102126 %
# <br>Training Top 3 Accuracy: 89.4736842105 %
# <br><br>While the accuracy metrics of the CNN was not as good as the best case lstm/gru models, the training time was record breaking fast at under a minute.

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout,Flatten
from keras.layers import Embedding
from keras.layers import Conv1D, GlobalAveragePooling1D, MaxPooling1D

modelc = Sequential()
modelc.add(Conv1D(64, 3, activation='relu', input_shape=[htrain_x.shape[1], htrain_x.shape[2]]))
modelc.add(Conv1D(64, 3, activation='relu'))
modelc.add(MaxPooling1D(3))
modelc.add(Conv1D(128, 3, activation='relu'))
modelc.add(Conv1D(128, 3, activation='relu'))
modelc.add(GlobalAveragePooling1D())    
modelc.add(Dense(512))
modelc.add(Activation('relu'))
modelc.add(Dropout(0.5))
modelc.add(Dense(19, activation='softmax'))

modelc.compile(loss='sparse_categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy',top3_acc])

history_c = modelc.fit(htrain_x, htrain_y, batch_size=64, epochs=128,validation_data=(htest_x, htest_y), verbose=2, shuffle=True)
# Out:
# Train on 114 samples, validate on 38 samples
# Epoch 1/128
# 1s - loss: 3.9247 - acc: 0.0702 - top3_acc: 0.1842 - val_loss: 2.7257 - val_acc: 0.0526 - val_top3_acc: 0.2368
# Epoch 2/128
# 0s - loss: 3.0039 - acc: 0.0877 - top3_acc: 0.2368 - val_loss: 2.6895 - val_acc: 0.0526 - val_top3_acc: 0.2632
# Epoch 3/128
# 0s - loss: 2.7243 - acc: 0.1228 - top3_acc: 0.2719 - val_loss: 2.6444 - val_acc: 0.1842 - val_top3_acc: 0.4211
# Epoch 4/128
# 0s - loss: 2.5941 - acc: 0.2018 - top3_acc: 0.4211 - val_loss: 2.6068 - val_acc: 0.1842 - val_top3_acc: 0.4211
# Epoch 5/128
# 0s - loss: 2.5323 - acc: 0.2456 - top3_acc: 0.4561 - val_loss: 2.5225 - val_acc: 0.2105 - val_top3_acc: 0.4737
# Epoch 6/128
# 0s - loss: 2.4415 - acc: 0.3246 - top3_acc: 0.4561 - val_loss: 2.4485 - val_acc: 0.2895 - val_top3_acc: 0.4474
# Epoch 7/128
# 0s - loss: 2.3152 - acc: 0.3333 - top3_acc: 0.5526 - val_loss: 2.3508 - val_acc: 0.3684 - val_top3_acc: 0.5526
# Epoch 8/128
# 0s - loss: 2.1464 - acc: 0.3684 - top3_acc: 0.6228 - val_loss: 2.1999 - val_acc: 0.3947 - val_top3_acc: 0.5526
# Epoch 9/128
# 0s - loss: 1.9630 - acc: 0.4298 - top3_acc: 0.6754 - val_loss: 1.9674 - val_acc: 0.3947 - val_top3_acc: 0.6053
# Epoch 10/128
# 0s - loss: 1.7367 - acc: 0.4825 - top3_acc: 0.7544 - val_loss: 1.8115 - val_acc: 0.4474 - val_top3_acc: 0.6842
# Epoch 11/128
# 0s - loss: 1.5933 - acc: 0.5175 - top3_acc: 0.7719 - val_loss: 1.7553 - val_acc: 0.4474 - val_top3_acc: 0.7368
# Epoch 12/128
# 0s - loss: 1.4216 - acc: 0.5439 - top3_acc: 0.8070 - val_loss: 1.6669 - val_acc: 0.5000 - val_top3_acc: 0.7632
# Epoch 13/128
# 0s - loss: 1.1699 - acc: 0.6053 - top3_acc: 0.8684 - val_loss: 1.5799 - val_acc: 0.5526 - val_top3_acc: 0.7632
# Epoch 14/128
# 0s - loss: 1.1547 - acc: 0.5877 - top3_acc: 0.8860 - val_loss: 1.3728 - val_acc: 0.6053 - val_top3_acc: 0.8158
# Epoch 15/128
# 0s - loss: 1.0560 - acc: 0.6228 - top3_acc: 0.8772 - val_loss: 1.3200 - val_acc: 0.6053 - val_top3_acc: 0.8684
# Epoch 16/128
# 0s - loss: 0.9532 - acc: 0.6316 - top3_acc: 0.9123 - val_loss: 1.6268 - val_acc: 0.6316 - val_top3_acc: 0.8684
# Epoch 17/128
# 0s - loss: 0.9060 - acc: 0.6491 - top3_acc: 0.8947 - val_loss: 1.4290 - val_acc: 0.6053 - val_top3_acc: 0.8947
# Epoch 18/128
# 0s - loss: 0.7817 - acc: 0.6754 - top3_acc: 0.9298 - val_loss: 1.5320 - val_acc: 0.5526 - val_top3_acc: 0.8158
# Epoch 19/128
# 0s - loss: 0.8486 - acc: 0.6579 - top3_acc: 0.9123 - val_loss: 1.2478 - val_acc: 0.6316 - val_top3_acc: 0.8684
# Epoch 20/128
# 0s - loss: 0.7528 - acc: 0.7018 - top3_acc: 0.9649 - val_loss: 1.1702 - val_acc: 0.6053 - val_top3_acc: 0.8421
# Epoch 21/128
# 0s - loss: 0.7223 - acc: 0.7368 - top3_acc: 0.9561 - val_loss: 1.0966 - val_acc: 0.6842 - val_top3_acc: 0.8684
# Epoch 22/128
# 0s - loss: 0.6216 - acc: 0.7719 - top3_acc: 0.9649 - val_loss: 1.1291 - val_acc: 0.6579 - val_top3_acc: 0.8684
# Epoch 23/128
# 0s - loss: 0.5728 - acc: 0.8070 - top3_acc: 0.9561 - val_loss: 1.4128 - val_acc: 0.6053 - val_top3_acc: 0.8421
# Epoch 24/128
# 0s - loss: 0.5645 - acc: 0.8070 - top3_acc: 0.9825 - val_loss: 1.4582 - val_acc: 0.7632 - val_top3_acc: 0.8684
# Epoch 25/128
# 0s - loss: 0.4235 - acc: 0.8421 - top3_acc: 0.9825 - val_loss: 1.5340 - val_acc: 0.6316 - val_top3_acc: 0.8947
# Epoch 26/128
# 0s - loss: 0.4704 - acc: 0.7895 - top3_acc: 0.9912 - val_loss: 1.6314 - val_acc: 0.6842 - val_top3_acc: 0.8947
# Epoch 27/128
# 0s - loss: 0.5831 - acc: 0.7895 - top3_acc: 0.9912 - val_loss: 1.1830 - val_acc: 0.7368 - val_top3_acc: 0.9211
# Epoch 28/128
# 0s - loss: 0.4511 - acc: 0.8596 - top3_acc: 0.9825 - val_loss: 1.1470 - val_acc: 0.6842 - val_top3_acc: 0.8947
# Epoch 29/128
# 0s - loss: 0.4769 - acc: 0.8333 - top3_acc: 0.9912 - val_loss: 1.0822 - val_acc: 0.7105 - val_top3_acc: 0.9211
# Epoch 30/128
# 0s - loss: 0.4012 - acc: 0.8509 - top3_acc: 1.0000 - val_loss: 1.0044 - val_acc: 0.7105 - val_top3_acc: 0.8947
# Epoch 31/128
# 0s - loss: 0.3796 - acc: 0.8772 - top3_acc: 1.0000 - val_loss: 1.0895 - val_acc: 0.6579 - val_top3_acc: 0.8684
# Epoch 32/128
# 0s - loss: 0.3453 - acc: 0.8860 - top3_acc: 0.9912 - val_loss: 0.9699 - val_acc: 0.7368 - val_top3_acc: 0.8947
# Epoch 33/128
# 0s - loss: 0.3169 - acc: 0.8860 - top3_acc: 1.0000 - val_loss: 0.9435 - val_acc: 0.7632 - val_top3_acc: 0.8947
# Epoch 34/128
# 0s - loss: 0.2431 - acc: 0.9035 - top3_acc: 1.0000 - val_loss: 0.8913 - val_acc: 0.7368 - val_top3_acc: 0.9211
# Epoch 35/128
# 0s - loss: 0.3434 - acc: 0.8860 - top3_acc: 0.9912 - val_loss: 0.9076 - val_acc: 0.7368 - val_top3_acc: 0.9211
# Epoch 36/128
# 0s - loss: 0.2835 - acc: 0.8947 - top3_acc: 1.0000 - val_loss: 1.0508 - val_acc: 0.7368 - val_top3_acc: 0.8947
# Epoch 37/128
# 0s - loss: 0.2787 - acc: 0.9211 - top3_acc: 1.0000 - val_loss: 1.1139 - val_acc: 0.7368 - val_top3_acc: 0.8947
# Epoch 38/128
# 0s - loss: 0.2487 - acc: 0.9035 - top3_acc: 1.0000 - val_loss: 0.9605 - val_acc: 0.7368 - val_top3_acc: 0.8947
# Epoch 39/128
# 0s - loss: 0.2193 - acc: 0.9123 - top3_acc: 1.0000 - val_loss: 1.5214 - val_acc: 0.7105 - val_top3_acc: 0.9211
# Epoch 40/128
# 0s - loss: 0.2596 - acc: 0.9123 - top3_acc: 1.0000 - val_loss: 1.3892 - val_acc: 0.6842 - val_top3_acc: 0.9211
# Epoch 41/128
# 0s - loss: 0.1997 - acc: 0.9474 - top3_acc: 1.0000 - val_loss: 1.2093 - val_acc: 0.6842 - val_top3_acc: 0.9211
# Epoch 42/128
# 0s - loss: 0.1501 - acc: 0.9649 - top3_acc: 1.0000 - val_loss: 1.2022 - val_acc: 0.6842 - val_top3_acc: 0.9211
# Epoch 43/128
# 0s - loss: 0.1798 - acc: 0.9386 - top3_acc: 1.0000 - val_loss: 1.3185 - val_acc: 0.7105 - val_top3_acc: 0.9211
# Epoch 44/128
# 0s - loss: 0.1432 - acc: 0.9561 - top3_acc: 1.0000 - val_loss: 1.4072 - val_acc: 0.6842 - val_top3_acc: 0.9211
# Epoch 45/128
# 0s - loss: 0.1408 - acc: 0.9561 - top3_acc: 1.0000 - val_loss: 1.5868 - val_acc: 0.7105 - val_top3_acc: 0.9211
# Epoch 46/128
# 0s - loss: 0.1376 - acc: 0.9561 - top3_acc: 1.0000 - val_loss: 1.5148 - val_acc: 0.6842 - val_top3_acc: 0.8947
# Epoch 47/128
# 0s - loss: 0.0965 - acc: 0.9649 - top3_acc: 1.0000 - val_loss: 1.2017 - val_acc: 0.6316 - val_top3_acc: 0.8947
# Epoch 48/128
# 0s - loss: 0.0786 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 1.0862 - val_acc: 0.7105 - val_top3_acc: 0.8947
# Epoch 49/128
# 0s - loss: 0.1150 - acc: 0.9649 - top3_acc: 1.0000 - val_loss: 1.3180 - val_acc: 0.6842 - val_top3_acc: 0.8421
# Epoch 50/128
# 0s - loss: 0.2443 - acc: 0.9123 - top3_acc: 0.9912 - val_loss: 1.0969 - val_acc: 0.7895 - val_top3_acc: 0.9211
# Epoch 51/128
# 0s - loss: 0.1847 - acc: 0.9474 - top3_acc: 0.9912 - val_loss: 1.0273 - val_acc: 0.7895 - val_top3_acc: 0.9211
# Epoch 52/128
# 0s - loss: 0.0859 - acc: 0.9649 - top3_acc: 1.0000 - val_loss: 1.4450 - val_acc: 0.6579 - val_top3_acc: 0.9474
# Epoch 53/128
# 0s - loss: 0.1044 - acc: 0.9649 - top3_acc: 1.0000 - val_loss: 1.6461 - val_acc: 0.7105 - val_top3_acc: 0.9211
# Epoch 54/128
# 0s - loss: 0.1222 - acc: 0.9649 - top3_acc: 1.0000 - val_loss: 1.4082 - val_acc: 0.7368 - val_top3_acc: 0.9211
# Epoch 55/128
# 0s - loss: 0.0807 - acc: 0.9737 - top3_acc: 1.0000 - val_loss: 1.2162 - val_acc: 0.7368 - val_top3_acc: 0.9211
# Epoch 56/128
# 0s - loss: 0.0747 - acc: 0.9737 - top3_acc: 1.0000 - val_loss: 1.2489 - val_acc: 0.6842 - val_top3_acc: 0.9211
# Epoch 57/128
# 0s - loss: 0.1102 - acc: 0.9561 - top3_acc: 1.0000 - val_loss: 1.1435 - val_acc: 0.7632 - val_top3_acc: 0.9211
# Epoch 58/128
# 0s - loss: 0.0762 - acc: 0.9649 - top3_acc: 1.0000 - val_loss: 1.1026 - val_acc: 0.8158 - val_top3_acc: 0.9211
# Epoch 59/128
# 0s - loss: 0.0720 - acc: 0.9737 - top3_acc: 1.0000 - val_loss: 1.0616 - val_acc: 0.8158 - val_top3_acc: 0.9211
# Epoch 60/128
# 0s - loss: 0.0645 - acc: 0.9737 - top3_acc: 1.0000 - val_loss: 1.2357 - val_acc: 0.7632 - val_top3_acc: 0.9211
# Epoch 61/128
# 0s - loss: 0.0542 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 1.8954 - val_acc: 0.6842 - val_top3_acc: 0.9211
# Epoch 62/128
# 0s - loss: 0.0648 - acc: 0.9737 - top3_acc: 1.0000 - val_loss: 1.9068 - val_acc: 0.6842 - val_top3_acc: 0.9211
# Epoch 63/128
# 0s - loss: 0.0534 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 1.3987 - val_acc: 0.7895 - val_top3_acc: 0.9211
# Epoch 64/128
# 0s - loss: 0.1347 - acc: 0.9649 - top3_acc: 1.0000 - val_loss: 0.9972 - val_acc: 0.8158 - val_top3_acc: 0.9474
# Epoch 65/128
# 0s - loss: 0.1050 - acc: 0.9649 - top3_acc: 1.0000 - val_loss: 1.2107 - val_acc: 0.7632 - val_top3_acc: 0.9211
# Epoch 66/128
# 0s - loss: 0.0769 - acc: 0.9737 - top3_acc: 1.0000 - val_loss: 1.2925 - val_acc: 0.7368 - val_top3_acc: 0.9211
# Epoch 67/128
# 0s - loss: 0.0816 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 1.3242 - val_acc: 0.7368 - val_top3_acc: 0.9211
# Epoch 68/128
# 0s - loss: 0.0584 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 1.5029 - val_acc: 0.7105 - val_top3_acc: 0.8947
# Epoch 69/128
# 0s - loss: 0.0770 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 1.3612 - val_acc: 0.7368 - val_top3_acc: 0.9211
# Epoch 70/128
# 0s - loss: 0.0714 - acc: 0.9649 - top3_acc: 1.0000 - val_loss: 1.3695 - val_acc: 0.7368 - val_top3_acc: 0.9211
# Epoch 71/128
# 0s - loss: 0.0892 - acc: 0.9737 - top3_acc: 1.0000 - val_loss: 1.7316 - val_acc: 0.6842 - val_top3_acc: 0.9211
# Epoch 72/128
# 0s - loss: 0.0941 - acc: 0.9649 - top3_acc: 1.0000 - val_loss: 1.4488 - val_acc: 0.7895 - val_top3_acc: 0.9211
# Epoch 73/128
# 0s - loss: 0.0753 - acc: 0.9649 - top3_acc: 1.0000 - val_loss: 1.4649 - val_acc: 0.6842 - val_top3_acc: 0.9211
# Epoch 74/128
# 0s - loss: 0.0489 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 1.4596 - val_acc: 0.7368 - val_top3_acc: 0.9211
# Epoch 75/128
# 0s - loss: 0.0429 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 1.2889 - val_acc: 0.7632 - val_top3_acc: 0.9211
# Epoch 76/128
# 0s - loss: 0.0396 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 1.3196 - val_acc: 0.7105 - val_top3_acc: 0.9211
# Epoch 77/128
# 0s - loss: 0.0737 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 1.2114 - val_acc: 0.8158 - val_top3_acc: 0.9211
# Epoch 78/128
# 0s - loss: 0.0107 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 1.5910 - val_acc: 0.7105 - val_top3_acc: 0.9211
# Epoch 79/128
# 0s - loss: 0.0517 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 1.5709 - val_acc: 0.6579 - val_top3_acc: 0.9211
# Epoch 80/128
# 0s - loss: 0.0432 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 1.4974 - val_acc: 0.7368 - val_top3_acc: 0.9211
# Epoch 81/128
# 0s - loss: 0.0318 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 1.2464 - val_acc: 0.7632 - val_top3_acc: 0.9211
# Epoch 82/128
# 0s - loss: 0.0521 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 1.2068 - val_acc: 0.7632 - val_top3_acc: 0.9211
# Epoch 83/128
# 0s - loss: 0.0343 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 1.2757 - val_acc: 0.7632 - val_top3_acc: 0.9211
# Epoch 84/128
# 0s - loss: 0.0199 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 1.2688 - val_acc: 0.8158 - val_top3_acc: 0.8947
# Epoch 85/128
# 0s - loss: 0.0154 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 1.1401 - val_acc: 0.8158 - val_top3_acc: 0.9211
# Epoch 86/128
# 0s - loss: 0.0477 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 1.2320 - val_acc: 0.7105 - val_top3_acc: 0.9211
# Epoch 87/128
# 0s - loss: 0.0274 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 1.3386 - val_acc: 0.7105 - val_top3_acc: 0.9474
# Epoch 88/128
# 0s - loss: 0.0152 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 1.4387 - val_acc: 0.7632 - val_top3_acc: 0.9474
# Epoch 89/128
# 0s - loss: 0.0581 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 1.1618 - val_acc: 0.8421 - val_top3_acc: 0.9211
# Epoch 90/128
# 0s - loss: 0.0337 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 1.2692 - val_acc: 0.7368 - val_top3_acc: 0.9211
# Epoch 91/128
# 0s - loss: 0.0584 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 1.2540 - val_acc: 0.7632 - val_top3_acc: 0.9211
# Epoch 92/128
# 0s - loss: 0.0264 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 1.5459 - val_acc: 0.7105 - val_top3_acc: 0.9211
# Epoch 93/128
# 0s - loss: 0.0842 - acc: 0.9561 - top3_acc: 1.0000 - val_loss: 1.2462 - val_acc: 0.7895 - val_top3_acc: 0.9474
# Epoch 94/128
# 0s - loss: 0.0985 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 1.3046 - val_acc: 0.7368 - val_top3_acc: 0.9211
# Epoch 95/128
# 0s - loss: 0.0731 - acc: 0.9737 - top3_acc: 1.0000 - val_loss: 1.3031 - val_acc: 0.7632 - val_top3_acc: 0.8947
# Epoch 96/128
# 0s - loss: 0.1209 - acc: 0.9386 - top3_acc: 1.0000 - val_loss: 1.3594 - val_acc: 0.6842 - val_top3_acc: 0.9474
# Epoch 97/128
# 0s - loss: 0.0538 - acc: 0.9737 - top3_acc: 1.0000 - val_loss: 1.3656 - val_acc: 0.6579 - val_top3_acc: 0.9474
# Epoch 98/128
# 0s - loss: 0.0695 - acc: 0.9649 - top3_acc: 1.0000 - val_loss: 1.0805 - val_acc: 0.8158 - val_top3_acc: 0.9211
# Epoch 99/128
# 0s - loss: 0.1247 - acc: 0.9649 - top3_acc: 1.0000 - val_loss: 1.0916 - val_acc: 0.7895 - val_top3_acc: 0.9474
# Epoch 100/128
# 0s - loss: 0.0513 - acc: 0.9737 - top3_acc: 1.0000 - val_loss: 1.6914 - val_acc: 0.7105 - val_top3_acc: 0.9474
# Epoch 101/128
# 0s - loss: 0.0990 - acc: 0.9561 - top3_acc: 1.0000 - val_loss: 1.2167 - val_acc: 0.7105 - val_top3_acc: 0.9474
# Epoch 102/128
# 0s - loss: 0.0160 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 1.1921 - val_acc: 0.6842 - val_top3_acc: 0.9211
# Epoch 103/128
# 0s - loss: 0.1492 - acc: 0.9561 - top3_acc: 1.0000 - val_loss: 1.8219 - val_acc: 0.6842 - val_top3_acc: 0.9211
# Epoch 104/128
# 0s - loss: 0.1280 - acc: 0.9561 - top3_acc: 1.0000 - val_loss: 1.9101 - val_acc: 0.6842 - val_top3_acc: 0.9211
# Epoch 105/128
# 0s - loss: 0.0404 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 1.3319 - val_acc: 0.7632 - val_top3_acc: 0.8947
# Epoch 106/128
# 0s - loss: 0.0894 - acc: 0.9737 - top3_acc: 1.0000 - val_loss: 1.5652 - val_acc: 0.7105 - val_top3_acc: 0.9211
# Epoch 107/128
# 0s - loss: 0.0715 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 1.4778 - val_acc: 0.6842 - val_top3_acc: 0.9211
# Epoch 108/128
# 0s - loss: 0.1720 - acc: 0.9649 - top3_acc: 1.0000 - val_loss: 1.5071 - val_acc: 0.6842 - val_top3_acc: 0.9211
# Epoch 109/128
# 0s - loss: 0.0711 - acc: 0.9737 - top3_acc: 1.0000 - val_loss: 1.7561 - val_acc: 0.7105 - val_top3_acc: 0.9211
# Epoch 110/128
# 0s - loss: 0.0772 - acc: 0.9649 - top3_acc: 1.0000 - val_loss: 1.9293 - val_acc: 0.7368 - val_top3_acc: 0.9211
# Epoch 111/128
# 0s - loss: 0.0452 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 2.0647 - val_acc: 0.7105 - val_top3_acc: 0.9211
# Epoch 112/128
# 0s - loss: 0.0609 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 2.0908 - val_acc: 0.7368 - val_top3_acc: 0.8947
# Epoch 113/128
# 0s - loss: 0.0643 - acc: 0.9737 - top3_acc: 1.0000 - val_loss: 1.8581 - val_acc: 0.7368 - val_top3_acc: 0.8947
# Epoch 114/128
# 0s - loss: 0.0436 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 1.8560 - val_acc: 0.7368 - val_top3_acc: 0.9211
# Epoch 115/128
# 0s - loss: 0.0457 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 1.7328 - val_acc: 0.7368 - val_top3_acc: 0.9211
# Epoch 116/128
# 0s - loss: 0.0365 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 1.4766 - val_acc: 0.7368 - val_top3_acc: 0.9211
# Epoch 117/128
# 0s - loss: 0.0252 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 1.5015 - val_acc: 0.7895 - val_top3_acc: 0.8947
# Epoch 118/128
# 0s - loss: 0.0723 - acc: 0.9737 - top3_acc: 1.0000 - val_loss: 1.2542 - val_acc: 0.8158 - val_top3_acc: 0.9211
# Epoch 119/128
# 0s - loss: 0.0256 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 1.2982 - val_acc: 0.8158 - val_top3_acc: 0.9211
# Epoch 120/128
# 0s - loss: 0.0520 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 1.4313 - val_acc: 0.7895 - val_top3_acc: 0.9211
# Epoch 121/128
# 0s - loss: 0.0177 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 1.7960 - val_acc: 0.7105 - val_top3_acc: 0.9211
# Epoch 122/128
# 0s - loss: 0.0518 - acc: 0.9737 - top3_acc: 1.0000 - val_loss: 1.6435 - val_acc: 0.7368 - val_top3_acc: 0.9211
# Epoch 123/128
# 0s - loss: 0.0091 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 1.6209 - val_acc: 0.7368 - val_top3_acc: 0.9211
# Epoch 124/128
# 0s - loss: 0.0756 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 1.4636 - val_acc: 0.7895 - val_top3_acc: 0.9211
# Epoch 125/128
# 0s - loss: 0.0231 - acc: 1.0000 - top3_acc: 1.0000 - val_loss: 1.4051 - val_acc: 0.7895 - val_top3_acc: 0.8947
# Epoch 126/128
# 0s - loss: 0.0191 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 1.6750 - val_acc: 0.7368 - val_top3_acc: 0.8684
# Epoch 127/128
# 0s - loss: 0.0439 - acc: 0.9912 - top3_acc: 1.0000 - val_loss: 1.7194 - val_acc: 0.6842 - val_top3_acc: 0.8947
# Epoch 128/128
# 0s - loss: 0.0283 - acc: 0.9825 - top3_acc: 1.0000 - val_loss: 1.5949 - val_acc: 0.7368 - val_top3_acc: 0.8947
# 32/38 [========================>.....] - ETA: 0s

# %%
scores = modelc.evaluate(htrain_x, htrain_y, verbose=1)
print('Training Loss:', scores[0])
print('Training Accuracy:', scores[1]*100,'%')
print('Training Top 3 Accuracy:', scores[2]*100,'%')
scores = modelc.evaluate(htest_x, htest_y, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1]*100,'%')
print('Training Top 3 Accuracy:', scores[2]*100,'%')
# Out:
#  96/114 [========================>.....] - ETA: 0sTraining Loss: 0.00405181182029
# Training Accuracy: 100.0 %
# Training Top 3 Accuracy: 100.0 %
# 32/38 [========================>.....] - ETA: 0sTest loss: 1.59485659474
# Test accuracy: 73.6842102126 %
# Training Top 3 Accuracy: 89.4736842105 %

# %% [markdown]
# ## Conclusion
# We investigate inter-activity variability based on a publicly available activity dataset available at uci machine learning repository, and provided some definitions that quantify such variability. We considered pre-processing the acquired time sequences and feature vectors in different ways and generated 3 pairs of training and test feature vectors. We used one subject of each sex in the test set to reduce bias error.<br>
# We observed the similarities between various activity and classified activities readings into static, periodic and random fluctuations. We also defined a fair boundary between the acitivities that allowed us to classify the activities based on their sensor readings.<br>
# This experiment tells us how powerful wearable sensors can be in predicting the activities performed by the person, which can have countless use cases in the new era of wearable smart technology.<br>
# We did notice some activities have trouble being classified correctly, especially when they have close neighbors. however it should be tackleable by increasing the complexity of the feature extraction, since we only used common operations(even though they proved to be extremely useful too).
# <br>The experiment covered an extremly wide spectrum of activities which proves that these models can be applied in all sorts of sensor datasets, an interesting to ponder can be a classifier which can predict the type of dance using the sensor readings from the dancer.
# <br><br>
# This experiment had a completion time frame involved so there is still a of space for improvement in it. Some things to implement in the future include splitting the training and test sets based on the time series instead of subjects, using more complex features for the training sets using methods such as pca, dft and correlations, and experiment with deeper neural networks.

# %% [markdown]
# ### References
# * K. Altun, B. Barshan, and O. Tunçel,<br>
# "Comparative study on classifying human activities with miniature inertial and magnetic sensors,"<br>
# Pattern Recognition, 43(10):3605-3620, October 2010.
# * Billur Barshan and Aras Yurtm,<br>
# "Investigating Inter-Subject and Inter-Activity Variations in Activity Recognition Using Wearable Motion Sensors"<br>
# Department of Electrical and Electronics Engineering, Bilkent University, Bilkent, TR-06800 Ankara, Turkey
